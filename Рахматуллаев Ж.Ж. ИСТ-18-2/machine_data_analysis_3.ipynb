# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 12
second_hidden_layer_size = 12
output_layer_size = 1
epochs_number = 50
batch_size = 64

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 575us/step - loss: 1.2660 - mean_absolute_error: 0.9596 - mean_squared_error: 1.2660 - val_loss: 1.2210 - val_mean_absolute_error: 0.9691 - val_mean_squared_error: 1.2210
# Epoch 2/50
# 242/242 [==============================] - 0s 28us/step - loss: 1.2160 - mean_absolute_error: 0.9379 - mean_squared_error: 1.2160 - val_loss: 1.1783 - val_mean_absolute_error: 0.9494 - val_mean_squared_error: 1.1783
# Epoch 3/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.1736 - mean_absolute_error: 0.9187 - mean_squared_error: 1.1736 - val_loss: 1.1425 - val_mean_absolute_error: 0.9313 - val_mean_squared_error: 1.1425
# Epoch 4/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.1376 - mean_absolute_error: 0.9021 - mean_squared_error: 1.1376 - val_loss: 1.1116 - val_mean_absolute_error: 0.9148 - val_mean_squared_error: 1.1116
# Epoch 5/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.1083 - mean_absolute_error: 0.8871 - mean_squared_error: 1.1083 - val_loss: 1.0867 - val_mean_absolute_error: 0.9006 - val_mean_squared_error: 1.0867
# Epoch 6/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0855 - mean_absolute_error: 0.8754 - mean_squared_error: 1.0855 - val_loss: 1.0658 - val_mean_absolute_error: 0.8882 - val_mean_squared_error: 1.0658
# Epoch 7/50
# 242/242 [==============================] - 0s 30us/step - loss: 1.0663 - mean_absolute_error: 0.8645 - mean_squared_error: 1.0663 - val_loss: 1.0488 - val_mean_absolute_error: 0.8773 - val_mean_squared_error: 1.0488
# Epoch 8/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0496 - mean_absolute_error: 0.8542 - mean_squared_error: 1.0496 - val_loss: 1.0341 - val_mean_absolute_error: 0.8680 - val_mean_squared_error: 1.0341
# Epoch 9/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0359 - mean_absolute_error: 0.8466 - mean_squared_error: 1.0359 - val_loss: 1.0220 - val_mean_absolute_error: 0.8599 - val_mean_squared_error: 1.0220
# Epoch 10/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0250 - mean_absolute_error: 0.8395 - mean_squared_error: 1.0250 - val_loss: 1.0118 - val_mean_absolute_error: 0.8526 - val_mean_squared_error: 1.0118
# Epoch 11/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0161 - mean_absolute_error: 0.8338 - mean_squared_error: 1.0161 - val_loss: 1.0024 - val_mean_absolute_error: 0.8463 - val_mean_squared_error: 1.0024
# Epoch 12/50
# 242/242 [==============================] - 0s 29us/step - loss: 1.0076 - mean_absolute_error: 0.8284 - mean_squared_error: 1.0076 - val_loss: 0.9948 - val_mean_absolute_error: 0.8407 - val_mean_squared_error: 0.9948
# Epoch 13/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9998 - mean_absolute_error: 0.8236 - mean_squared_error: 0.9998 - val_loss: 0.9878 - val_mean_absolute_error: 0.8358 - val_mean_squared_error: 0.9878
# Epoch 14/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.9924 - mean_absolute_error: 0.8192 - mean_squared_error: 0.9924 - val_loss: 0.9818 - val_mean_absolute_error: 0.8317 - val_mean_squared_error: 0.9818
# Epoch 15/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9861 - mean_absolute_error: 0.8153 - mean_squared_error: 0.9861 - val_loss: 0.9759 - val_mean_absolute_error: 0.8276 - val_mean_squared_error: 0.9759
# Epoch 16/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9802 - mean_absolute_error: 0.8120 - mean_squared_error: 0.9802 - val_loss: 0.9694 - val_mean_absolute_error: 0.8235 - val_mean_squared_error: 0.9694
# Epoch 17/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9749 - mean_absolute_error: 0.8088 - mean_squared_error: 0.9749 - val_loss: 0.9628 - val_mean_absolute_error: 0.8193 - val_mean_squared_error: 0.9628
# Epoch 18/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9691 - mean_absolute_error: 0.8055 - mean_squared_error: 0.9691 - val_loss: 0.9566 - val_mean_absolute_error: 0.8154 - val_mean_squared_error: 0.9566
# Epoch 19/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.9638 - mean_absolute_error: 0.8027 - mean_squared_error: 0.9638 - val_loss: 0.9509 - val_mean_absolute_error: 0.8121 - val_mean_squared_error: 0.9509
# Epoch 20/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9585 - mean_absolute_error: 0.8000 - mean_squared_error: 0.9585 - val_loss: 0.9447 - val_mean_absolute_error: 0.8089 - val_mean_squared_error: 0.9447
# Epoch 21/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9534 - mean_absolute_error: 0.7976 - mean_squared_error: 0.9534 - val_loss: 0.9385 - val_mean_absolute_error: 0.8058 - val_mean_squared_error: 0.9385
# Epoch 22/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9485 - mean_absolute_error: 0.7954 - mean_squared_error: 0.9485 - val_loss: 0.9327 - val_mean_absolute_error: 0.8028 - val_mean_squared_error: 0.9327
# Epoch 23/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9437 - mean_absolute_error: 0.7930 - mean_squared_error: 0.9437 - val_loss: 0.9274 - val_mean_absolute_error: 0.8000 - val_mean_squared_error: 0.9274
# Epoch 24/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9386 - mean_absolute_error: 0.7906 - mean_squared_error: 0.9386 - val_loss: 0.9219 - val_mean_absolute_error: 0.7974 - val_mean_squared_error: 0.9219
# Epoch 25/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9339 - mean_absolute_error: 0.7883 - mean_squared_error: 0.9339 - val_loss: 0.9168 - val_mean_absolute_error: 0.7948 - val_mean_squared_error: 0.9168
# Epoch 26/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9294 - mean_absolute_error: 0.7859 - mean_squared_error: 0.9294 - val_loss: 0.9122 - val_mean_absolute_error: 0.7923 - val_mean_squared_error: 0.9122
# Epoch 27/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9243 - mean_absolute_error: 0.7835 - mean_squared_error: 0.9243 - val_loss: 0.9067 - val_mean_absolute_error: 0.7897 - val_mean_squared_error: 0.9067
# Epoch 28/50
# 242/242 [==============================] - 0s 27us/step - loss: 0.9192 - mean_absolute_error: 0.7810 - mean_squared_error: 0.9192 - val_loss: 0.9013 - val_mean_absolute_error: 0.7869 - val_mean_squared_error: 0.9013
# Epoch 29/50
# 242/242 [==============================] - 0s 27us/step - loss: 0.9144 - mean_absolute_error: 0.7787 - mean_squared_error: 0.9144 - val_loss: 0.8968 - val_mean_absolute_error: 0.7844 - val_mean_squared_error: 0.8968
# Epoch 30/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9095 - mean_absolute_error: 0.7761 - mean_squared_error: 0.9095 - val_loss: 0.8915 - val_mean_absolute_error: 0.7816 - val_mean_squared_error: 0.8915
# Epoch 31/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.9038 - mean_absolute_error: 0.7735 - mean_squared_error: 0.9038 - val_loss: 0.8858 - val_mean_absolute_error: 0.7788 - val_mean_squared_error: 0.8858
# Epoch 32/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.8981 - mean_absolute_error: 0.7708 - mean_squared_error: 0.8981 - val_loss: 0.8800 - val_mean_absolute_error: 0.7755 - val_mean_squared_error: 0.8800
# Epoch 33/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8917 - mean_absolute_error: 0.7680 - mean_squared_error: 0.8917 - val_loss: 0.8723 - val_mean_absolute_error: 0.7714 - val_mean_squared_error: 0.8723
# Epoch 34/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8856 - mean_absolute_error: 0.7653 - mean_squared_error: 0.8856 - val_loss: 0.8650 - val_mean_absolute_error: 0.7673 - val_mean_squared_error: 0.8650
# Epoch 35/50
# 242/242 [==============================] - 0s 27us/step - loss: 0.8786 - mean_absolute_error: 0.7623 - mean_squared_error: 0.8786 - val_loss: 0.8577 - val_mean_absolute_error: 0.7635 - val_mean_squared_error: 0.8577
# Epoch 36/50
# 242/242 [==============================] - 0s 27us/step - loss: 0.8705 - mean_absolute_error: 0.7589 - mean_squared_error: 0.8705 - val_loss: 0.8498 - val_mean_absolute_error: 0.7593 - val_mean_squared_error: 0.8498
# Epoch 37/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8624 - mean_absolute_error: 0.7555 - mean_squared_error: 0.8624 - val_loss: 0.8407 - val_mean_absolute_error: 0.7546 - val_mean_squared_error: 0.8407
# Epoch 38/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.8541 - mean_absolute_error: 0.7518 - mean_squared_error: 0.8541 - val_loss: 0.8285 - val_mean_absolute_error: 0.7495 - val_mean_squared_error: 0.8285
# Epoch 39/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8452 - mean_absolute_error: 0.7482 - mean_squared_error: 0.8452 - val_loss: 0.8170 - val_mean_absolute_error: 0.7441 - val_mean_squared_error: 0.8170
# Epoch 40/50
# 242/242 [==============================] - 0s 30us/step - loss: 0.8343 - mean_absolute_error: 0.7439 - mean_squared_error: 0.8343 - val_loss: 0.8062 - val_mean_absolute_error: 0.7390 - val_mean_squared_error: 0.8062
# Epoch 41/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8244 - mean_absolute_error: 0.7395 - mean_squared_error: 0.8244 - val_loss: 0.7950 - val_mean_absolute_error: 0.7333 - val_mean_squared_error: 0.7950
# Epoch 42/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8152 - mean_absolute_error: 0.7356 - mean_squared_error: 0.8152 - val_loss: 0.7830 - val_mean_absolute_error: 0.7268 - val_mean_squared_error: 0.7830
# Epoch 43/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.8040 - mean_absolute_error: 0.7307 - mean_squared_error: 0.8040 - val_loss: 0.7733 - val_mean_absolute_error: 0.7209 - val_mean_squared_error: 0.7733
# Epoch 44/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.7934 - mean_absolute_error: 0.7255 - mean_squared_error: 0.7934 - val_loss: 0.7620 - val_mean_absolute_error: 0.7148 - val_mean_squared_error: 0.7620
# Epoch 45/50
# 242/242 [==============================] - 0s 32us/step - loss: 0.7821 - mean_absolute_error: 0.7204 - mean_squared_error: 0.7821 - val_loss: 0.7515 - val_mean_absolute_error: 0.7083 - val_mean_squared_error: 0.7515
# Epoch 46/50
# 242/242 [==============================] - 0s 31us/step - loss: 0.7725 - mean_absolute_error: 0.7161 - mean_squared_error: 0.7725 - val_loss: 0.7395 - val_mean_absolute_error: 0.7012 - val_mean_squared_error: 0.7395
# Epoch 47/50
# 242/242 [==============================] - 0s 28us/step - loss: 0.7642 - mean_absolute_error: 0.7120 - mean_squared_error: 0.7642 - val_loss: 0.7254 - val_mean_absolute_error: 0.6928 - val_mean_squared_error: 0.7254
# Epoch 48/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7065 - mean_squared_error: 0.7539 - val_loss: 0.7139 - val_mean_absolute_error: 0.6849 - val_mean_squared_error: 0.7139
# Epoch 49/50
# 242/242 [==============================] - 0s 30us/step - loss: 0.7450 - mean_absolute_error: 0.7012 - mean_squared_error: 0.7450 - val_loss: 0.7037 - val_mean_absolute_error: 0.6775 - val_mean_squared_error: 0.7037
# Epoch 50/50
# 242/242 [==============================] - 0s 29us/step - loss: 0.7386 - mean_absolute_error: 0.6975 - mean_squared_error: 0.7386 - val_loss: 0.6932 - val_mean_absolute_error: 0.6699 - val_mean_squared_error: 0.6932

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.8558563216308251
# 0.8325810526627364

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9746681451797485, p = 0.0002549212076701224
# Test k = 0.9699716567993164, p = 0.13880591094493866

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.975537121295929, p_s = 4.852562415180728e-05
# k_n = 12.748662423267268, p_n = 0.0017047595379833913

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('3_SimpleNeuralNetwork.h5')
