# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 12
second_hidden_layer_size = 12
output_layer_size = 1
epochs_number = 50
batch_size = 32

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 609us/step - loss: 1.7696 - mean_absolute_error: 1.0478 - mean_squared_error: 1.7696 - val_loss: 1.5821 - val_mean_absolute_error: 0.9881 - val_mean_squared_error: 1.5821
# Epoch 2/50
# 242/242 [==============================] - 0s 48us/step - loss: 1.4763 - mean_absolute_error: 0.9435 - mean_squared_error: 1.4763 - val_loss: 1.3808 - val_mean_absolute_error: 0.9411 - val_mean_squared_error: 1.3808
# Epoch 3/50
# 242/242 [==============================] - 0s 46us/step - loss: 1.2788 - mean_absolute_error: 0.8831 - mean_squared_error: 1.2788 - val_loss: 1.2743 - val_mean_absolute_error: 0.9185 - val_mean_squared_error: 1.2743
# Epoch 4/50
# 242/242 [==============================] - 0s 53us/step - loss: 1.1544 - mean_absolute_error: 0.8394 - mean_squared_error: 1.1544 - val_loss: 1.2053 - val_mean_absolute_error: 0.9065 - val_mean_squared_error: 1.2053
# Epoch 5/50
# 242/242 [==============================] - 0s 46us/step - loss: 1.0731 - mean_absolute_error: 0.8140 - mean_squared_error: 1.0731 - val_loss: 1.1599 - val_mean_absolute_error: 0.8968 - val_mean_squared_error: 1.1599
# Epoch 6/50
# 242/242 [==============================] - 0s 49us/step - loss: 1.0250 - mean_absolute_error: 0.8012 - mean_squared_error: 1.0250 - val_loss: 1.1239 - val_mean_absolute_error: 0.8884 - val_mean_squared_error: 1.1239
# Epoch 7/50
# 242/242 [==============================] - 0s 49us/step - loss: 0.9852 - mean_absolute_error: 0.7896 - mean_squared_error: 0.9852 - val_loss: 1.0931 - val_mean_absolute_error: 0.8789 - val_mean_squared_error: 1.0931
# Epoch 8/50
# 242/242 [==============================] - 0s 55us/step - loss: 0.9625 - mean_absolute_error: 0.7835 - mean_squared_error: 0.9625 - val_loss: 1.0617 - val_mean_absolute_error: 0.8666 - val_mean_squared_error: 1.0617
# Epoch 9/50
# 242/242 [==============================] - 0s 49us/step - loss: 0.9382 - mean_absolute_error: 0.7765 - mean_squared_error: 0.9382 - val_loss: 1.0319 - val_mean_absolute_error: 0.8538 - val_mean_squared_error: 1.0319
# Epoch 10/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.9220 - mean_absolute_error: 0.7706 - mean_squared_error: 0.9220 - val_loss: 1.0036 - val_mean_absolute_error: 0.8419 - val_mean_squared_error: 1.0036
# Epoch 11/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.9028 - mean_absolute_error: 0.7631 - mean_squared_error: 0.9028 - val_loss: 0.9794 - val_mean_absolute_error: 0.8319 - val_mean_squared_error: 0.9794
# Epoch 12/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.8885 - mean_absolute_error: 0.7565 - mean_squared_error: 0.8885 - val_loss: 0.9557 - val_mean_absolute_error: 0.8224 - val_mean_squared_error: 0.9557
# Epoch 13/50
# 242/242 [==============================] - 0s 71us/step - loss: 0.8714 - mean_absolute_error: 0.7499 - mean_squared_error: 0.8714 - val_loss: 0.9348 - val_mean_absolute_error: 0.8137 - val_mean_squared_error: 0.9348
# Epoch 14/50
# 242/242 [==============================] - 0s 59us/step - loss: 0.8566 - mean_absolute_error: 0.7437 - mean_squared_error: 0.8566 - val_loss: 0.9150 - val_mean_absolute_error: 0.8045 - val_mean_squared_error: 0.9150
# Epoch 15/50
# 242/242 [==============================] - 0s 85us/step - loss: 0.8425 - mean_absolute_error: 0.7379 - mean_squared_error: 0.8425 - val_loss: 0.8950 - val_mean_absolute_error: 0.7947 - val_mean_squared_error: 0.8950
# Epoch 16/50
# 242/242 [==============================] - 0s 82us/step - loss: 0.8270 - mean_absolute_error: 0.7320 - mean_squared_error: 0.8270 - val_loss: 0.8764 - val_mean_absolute_error: 0.7848 - val_mean_squared_error: 0.8764
# Epoch 17/50
# 242/242 [==============================] - 0s 93us/step - loss: 0.8143 - mean_absolute_error: 0.7271 - mean_squared_error: 0.8143 - val_loss: 0.8625 - val_mean_absolute_error: 0.7771 - val_mean_squared_error: 0.8625
# Epoch 18/50
# 242/242 [==============================] - 0s 86us/step - loss: 0.8011 - mean_absolute_error: 0.7224 - mean_squared_error: 0.8011 - val_loss: 0.8488 - val_mean_absolute_error: 0.7691 - val_mean_squared_error: 0.8488
# Epoch 19/50
# 242/242 [==============================] - 0s 88us/step - loss: 0.7913 - mean_absolute_error: 0.7186 - mean_squared_error: 0.7913 - val_loss: 0.8358 - val_mean_absolute_error: 0.7615 - val_mean_squared_error: 0.8358
# Epoch 20/50
# 242/242 [==============================] - 0s 53us/step - loss: 0.7790 - mean_absolute_error: 0.7132 - mean_squared_error: 0.7790 - val_loss: 0.8267 - val_mean_absolute_error: 0.7559 - val_mean_squared_error: 0.8267
# Epoch 21/50
# 242/242 [==============================] - 0s 51us/step - loss: 0.7706 - mean_absolute_error: 0.7105 - mean_squared_error: 0.7706 - val_loss: 0.8165 - val_mean_absolute_error: 0.7491 - val_mean_squared_error: 0.8165
# Epoch 22/50
# 242/242 [==============================] - 0s 52us/step - loss: 0.7624 - mean_absolute_error: 0.7072 - mean_squared_error: 0.7624 - val_loss: 0.8082 - val_mean_absolute_error: 0.7433 - val_mean_squared_error: 0.8082
# Epoch 23/50
# 242/242 [==============================] - 0s 51us/step - loss: 0.7533 - mean_absolute_error: 0.7037 - mean_squared_error: 0.7533 - val_loss: 0.8009 - val_mean_absolute_error: 0.7386 - val_mean_squared_error: 0.8009
# Epoch 24/50
# 242/242 [==============================] - 0s 56us/step - loss: 0.7452 - mean_absolute_error: 0.7006 - mean_squared_error: 0.7452 - val_loss: 0.7945 - val_mean_absolute_error: 0.7341 - val_mean_squared_error: 0.7945
# Epoch 25/50
# 242/242 [==============================] - 0s 52us/step - loss: 0.7400 - mean_absolute_error: 0.6993 - mean_squared_error: 0.7400 - val_loss: 0.7879 - val_mean_absolute_error: 0.7293 - val_mean_squared_error: 0.7879
# Epoch 26/50
# 242/242 [==============================] - 0s 51us/step - loss: 0.7326 - mean_absolute_error: 0.6954 - mean_squared_error: 0.7326 - val_loss: 0.7833 - val_mean_absolute_error: 0.7259 - val_mean_squared_error: 0.7833
# Epoch 27/50
# 242/242 [==============================] - 0s 52us/step - loss: 0.7284 - mean_absolute_error: 0.6937 - mean_squared_error: 0.7284 - val_loss: 0.7794 - val_mean_absolute_error: 0.7224 - val_mean_squared_error: 0.7794
# Epoch 28/50
# 242/242 [==============================] - 0s 51us/step - loss: 0.7246 - mean_absolute_error: 0.6912 - mean_squared_error: 0.7246 - val_loss: 0.7745 - val_mean_absolute_error: 0.7200 - val_mean_squared_error: 0.7745
# Epoch 29/50
# 242/242 [==============================] - 0s 53us/step - loss: 0.7195 - mean_absolute_error: 0.6890 - mean_squared_error: 0.7195 - val_loss: 0.7707 - val_mean_absolute_error: 0.7163 - val_mean_squared_error: 0.7707
# Epoch 30/50
# 242/242 [==============================] - 0s 68us/step - loss: 0.7165 - mean_absolute_error: 0.6872 - mean_squared_error: 0.7165 - val_loss: 0.7670 - val_mean_absolute_error: 0.7134 - val_mean_squared_error: 0.7670
# Epoch 31/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.7140 - mean_absolute_error: 0.6861 - mean_squared_error: 0.7140 - val_loss: 0.7631 - val_mean_absolute_error: 0.7086 - val_mean_squared_error: 0.7631
# Epoch 32/50
# 242/242 [==============================] - 0s 50us/step - loss: 0.7096 - mean_absolute_error: 0.6839 - mean_squared_error: 0.7096 - val_loss: 0.7607 - val_mean_absolute_error: 0.7077 - val_mean_squared_error: 0.7607
# Epoch 33/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.7063 - mean_absolute_error: 0.6817 - mean_squared_error: 0.7063 - val_loss: 0.7567 - val_mean_absolute_error: 0.7055 - val_mean_squared_error: 0.7567
# Epoch 34/50
# 242/242 [==============================] - 0s 49us/step - loss: 0.7030 - mean_absolute_error: 0.6797 - mean_squared_error: 0.7030 - val_loss: 0.7542 - val_mean_absolute_error: 0.7044 - val_mean_squared_error: 0.7542
# Epoch 35/50
# 242/242 [==============================] - 0s 58us/step - loss: 0.7001 - mean_absolute_error: 0.6780 - mean_squared_error: 0.7001 - val_loss: 0.7516 - val_mean_absolute_error: 0.7017 - val_mean_squared_error: 0.7516
# Epoch 36/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.6965 - mean_absolute_error: 0.6762 - mean_squared_error: 0.6965 - val_loss: 0.7498 - val_mean_absolute_error: 0.7002 - val_mean_squared_error: 0.7498
# Epoch 37/50
# 242/242 [==============================] - 0s 49us/step - loss: 0.6945 - mean_absolute_error: 0.6753 - mean_squared_error: 0.6945 - val_loss: 0.7477 - val_mean_absolute_error: 0.6979 - val_mean_squared_error: 0.7477
# Epoch 38/50
# 242/242 [==============================] - 0s 46us/step - loss: 0.6916 - mean_absolute_error: 0.6739 - mean_squared_error: 0.6916 - val_loss: 0.7464 - val_mean_absolute_error: 0.6974 - val_mean_squared_error: 0.7464
# Epoch 39/50
# 242/242 [==============================] - 0s 45us/step - loss: 0.6898 - mean_absolute_error: 0.6728 - mean_squared_error: 0.6898 - val_loss: 0.7456 - val_mean_absolute_error: 0.6970 - val_mean_squared_error: 0.7456
# Epoch 40/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.6867 - mean_absolute_error: 0.6714 - mean_squared_error: 0.6867 - val_loss: 0.7427 - val_mean_absolute_error: 0.6939 - val_mean_squared_error: 0.7427
# Epoch 41/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.6840 - mean_absolute_error: 0.6706 - mean_squared_error: 0.6840 - val_loss: 0.7421 - val_mean_absolute_error: 0.6929 - val_mean_squared_error: 0.7421
# Epoch 42/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.6833 - mean_absolute_error: 0.6710 - mean_squared_error: 0.6833 - val_loss: 0.7418 - val_mean_absolute_error: 0.6922 - val_mean_squared_error: 0.7418
# Epoch 43/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.6797 - mean_absolute_error: 0.6691 - mean_squared_error: 0.6797 - val_loss: 0.7406 - val_mean_absolute_error: 0.6915 - val_mean_squared_error: 0.7406
# Epoch 44/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.6778 - mean_absolute_error: 0.6678 - mean_squared_error: 0.6778 - val_loss: 0.7402 - val_mean_absolute_error: 0.6913 - val_mean_squared_error: 0.7402
# Epoch 45/50
# 242/242 [==============================] - 0s 49us/step - loss: 0.6755 - mean_absolute_error: 0.6665 - mean_squared_error: 0.6755 - val_loss: 0.7402 - val_mean_absolute_error: 0.6911 - val_mean_squared_error: 0.7402
# Epoch 46/50
# 242/242 [==============================] - 0s 51us/step - loss: 0.6739 - mean_absolute_error: 0.6659 - mean_squared_error: 0.6739 - val_loss: 0.7399 - val_mean_absolute_error: 0.6906 - val_mean_squared_error: 0.7399
# Epoch 47/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.6720 - mean_absolute_error: 0.6651 - mean_squared_error: 0.6720 - val_loss: 0.7397 - val_mean_absolute_error: 0.6904 - val_mean_squared_error: 0.7397
# Epoch 48/50
# 242/242 [==============================] - 0s 48us/step - loss: 0.6702 - mean_absolute_error: 0.6641 - mean_squared_error: 0.6702 - val_loss: 0.7389 - val_mean_absolute_error: 0.6895 - val_mean_squared_error: 0.7389
# Epoch 49/50
# 242/242 [==============================] - 0s 47us/step - loss: 0.6678 - mean_absolute_error: 0.6627 - mean_squared_error: 0.6678 - val_loss: 0.7390 - val_mean_absolute_error: 0.6890 - val_mean_squared_error: 0.7390
# Epoch 50/50
# 242/242 [==============================] - 0s 50us/step - loss: 0.6671 - mean_absolute_error: 0.6632 - mean_squared_error: 0.6671 - val_loss: 0.7374 - val_mean_absolute_error: 0.6877 - val_mean_squared_error: 0.7374

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.8150528987762329
# 0.8587366919883804

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9860391616821289, p = 0.01823948509991169
# Test k = 0.9794664978981018, p = 0.395252525806427

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.985781192779541, p_s = 0.004350371193140745
# k_n = 8.463780849992272, p_n = 0.0145249063321796

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('2_SimpleNeuralNetwork.h5')
