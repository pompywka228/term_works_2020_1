# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>num</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.927622</td>
#       <td>1.0</td>
#       <td>1.000000</td>
#       <td>0.624287</td>
#       <td>-0.206993</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.090789</td>
#       <td>0.0</td>
#       <td>0.552201</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>-2.117138</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.454038</td>
#       <td>0.159591</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.444548</td>
#       <td>0.0</td>
#       <td>0.715169</td>
#       <td>0.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>-1.529863</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.454038</td>
#       <td>-0.864692</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.931137</td>
#       <td>0.0</td>
#       <td>0.398844</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.253797</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>-0.141353</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.141680</td>
#       <td>0.0</td>
#       <td>0.265991</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.355054</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.335019</td>
#       <td>2.100829</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.601134</td>
#       <td>1.0</td>
#       <td>0.210865</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>0.568560</td>
#       <td>-1.150460</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.008368</td>
#       <td>0.0</td>
#       <td>0.145476</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.253797</td>
#       <td>0.0</td>
#       <td>0.577350</td>
#       <td>0.568560</td>
#       <td>1.054214</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>0.212382</td>
#       <td>0.0</td>
#       <td>0.379044</td>
#       <td>0.707107</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>-1.125867</td>
#       <td>1.0</td>
#       <td>0.577350</td>
#       <td>0.335019</td>
#       <td>0.431579</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>0.966733</td>
#       <td>0.0</td>
#       <td>0.323580</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>-0.170168</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.909866</td>
#       <td>-0.982712</td>
#       <td>1.0</td>
#       <td>0.397544</td>
#       <td>0.563348</td>
#       <td>0.0</td>
#       <td>0.179818</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.355054</td>
#       <td>1.0</td>
#       <td>0.816497</td>
#       <td>0.679061</td>
#       <td>-1.750157</td>
#       <td>0.0</td>
#       <td>0.397544</td>
#       <td>1.002123</td>
#       <td>0.0</td>
#       <td>0.436427</td>
#       <td>1.000000</td>
#       <td>0.0</td>
#       <td>1.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
input_layer_size = 13
first_hidden_layer_size = 15
second_hidden_layer_size = 15
output_layer_size = 1
epochs_number = 50
batch_size = 26

# %%
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/50
# 242/242 [==============================] - 0s 632us/step - loss: 1.0246 - mean_absolute_error: 0.8231 - mean_squared_error: 1.0246 - val_loss: 0.9159 - val_mean_absolute_error: 0.7741 - val_mean_squared_error: 0.9159
# Epoch 2/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.9839 - mean_absolute_error: 0.8082 - mean_squared_error: 0.9839 - val_loss: 0.8597 - val_mean_absolute_error: 0.7499 - val_mean_squared_error: 0.8597
# Epoch 3/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.9463 - mean_absolute_error: 0.7927 - mean_squared_error: 0.9463 - val_loss: 0.8169 - val_mean_absolute_error: 0.7285 - val_mean_squared_error: 0.8169
# Epoch 4/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.9169 - mean_absolute_error: 0.7817 - mean_squared_error: 0.9169 - val_loss: 0.7867 - val_mean_absolute_error: 0.7164 - val_mean_squared_error: 0.7867
# Epoch 5/50
# 242/242 [==============================] - 0s 59us/step - loss: 0.8914 - mean_absolute_error: 0.7726 - mean_squared_error: 0.8914 - val_loss: 0.7566 - val_mean_absolute_error: 0.7041 - val_mean_squared_error: 0.7566
# Epoch 6/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.8659 - mean_absolute_error: 0.7631 - mean_squared_error: 0.8659 - val_loss: 0.7299 - val_mean_absolute_error: 0.6949 - val_mean_squared_error: 0.7299
# Epoch 7/50
# 242/242 [==============================] - 0s 59us/step - loss: 0.8493 - mean_absolute_error: 0.7573 - mean_squared_error: 0.8493 - val_loss: 0.7089 - val_mean_absolute_error: 0.6861 - val_mean_squared_error: 0.7089
# Epoch 8/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.8333 - mean_absolute_error: 0.7510 - mean_squared_error: 0.8333 - val_loss: 0.6928 - val_mean_absolute_error: 0.6788 - val_mean_squared_error: 0.6928
# Epoch 9/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.8191 - mean_absolute_error: 0.7429 - mean_squared_error: 0.8191 - val_loss: 0.6741 - val_mean_absolute_error: 0.6688 - val_mean_squared_error: 0.6741
# Epoch 10/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.8092 - mean_absolute_error: 0.7354 - mean_squared_error: 0.8092 - val_loss: 0.6587 - val_mean_absolute_error: 0.6595 - val_mean_squared_error: 0.6587
# Epoch 11/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.7955 - mean_absolute_error: 0.7281 - mean_squared_error: 0.7955 - val_loss: 0.6509 - val_mean_absolute_error: 0.6549 - val_mean_squared_error: 0.6509
# Epoch 12/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.7837 - mean_absolute_error: 0.7240 - mean_squared_error: 0.7837 - val_loss: 0.6411 - val_mean_absolute_error: 0.6479 - val_mean_squared_error: 0.6411
# Epoch 13/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.7732 - mean_absolute_error: 0.7194 - mean_squared_error: 0.7732 - val_loss: 0.6318 - val_mean_absolute_error: 0.6419 - val_mean_squared_error: 0.6318
# Epoch 14/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.7637 - mean_absolute_error: 0.7158 - mean_squared_error: 0.7637 - val_loss: 0.6239 - val_mean_absolute_error: 0.6353 - val_mean_squared_error: 0.6239
# Epoch 15/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.7555 - mean_absolute_error: 0.7125 - mean_squared_error: 0.7555 - val_loss: 0.6193 - val_mean_absolute_error: 0.6304 - val_mean_squared_error: 0.6193
# Epoch 16/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.7468 - mean_absolute_error: 0.7069 - mean_squared_error: 0.7468 - val_loss: 0.6117 - val_mean_absolute_error: 0.6241 - val_mean_squared_error: 0.6117
# Epoch 17/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.7397 - mean_absolute_error: 0.7033 - mean_squared_error: 0.7397 - val_loss: 0.6033 - val_mean_absolute_error: 0.6191 - val_mean_squared_error: 0.6033
# Epoch 18/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.7319 - mean_absolute_error: 0.6984 - mean_squared_error: 0.7319 - val_loss: 0.6000 - val_mean_absolute_error: 0.6156 - val_mean_squared_error: 0.6000
# Epoch 19/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.7251 - mean_absolute_error: 0.6934 - mean_squared_error: 0.7251 - val_loss: 0.5961 - val_mean_absolute_error: 0.6131 - val_mean_squared_error: 0.5961
# Epoch 20/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.7183 - mean_absolute_error: 0.6903 - mean_squared_error: 0.7183 - val_loss: 0.5916 - val_mean_absolute_error: 0.6099 - val_mean_squared_error: 0.5916
# Epoch 21/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.7116 - mean_absolute_error: 0.6877 - mean_squared_error: 0.7116 - val_loss: 0.5918 - val_mean_absolute_error: 0.6096 - val_mean_squared_error: 0.5918
# Epoch 22/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.7069 - mean_absolute_error: 0.6859 - mean_squared_error: 0.7069 - val_loss: 0.5928 - val_mean_absolute_error: 0.6096 - val_mean_squared_error: 0.5928
# Epoch 23/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.7000 - mean_absolute_error: 0.6820 - mean_squared_error: 0.7000 - val_loss: 0.5896 - val_mean_absolute_error: 0.6076 - val_mean_squared_error: 0.5896
# Epoch 24/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6953 - mean_absolute_error: 0.6778 - mean_squared_error: 0.6953 - val_loss: 0.5865 - val_mean_absolute_error: 0.6055 - val_mean_squared_error: 0.5865
# Epoch 25/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.6889 - mean_absolute_error: 0.6733 - mean_squared_error: 0.6889 - val_loss: 0.5822 - val_mean_absolute_error: 0.6038 - val_mean_squared_error: 0.5822
# Epoch 26/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.6830 - mean_absolute_error: 0.6693 - mean_squared_error: 0.6830 - val_loss: 0.5804 - val_mean_absolute_error: 0.6027 - val_mean_squared_error: 0.5804
# Epoch 27/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6779 - mean_absolute_error: 0.6655 - mean_squared_error: 0.6779 - val_loss: 0.5803 - val_mean_absolute_error: 0.6032 - val_mean_squared_error: 0.5803
# Epoch 28/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6727 - mean_absolute_error: 0.6616 - mean_squared_error: 0.6727 - val_loss: 0.5798 - val_mean_absolute_error: 0.6028 - val_mean_squared_error: 0.5798
# Epoch 29/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.6703 - mean_absolute_error: 0.6617 - mean_squared_error: 0.6703 - val_loss: 0.5815 - val_mean_absolute_error: 0.6019 - val_mean_squared_error: 0.5815
# Epoch 30/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.6627 - mean_absolute_error: 0.6576 - mean_squared_error: 0.6627 - val_loss: 0.5755 - val_mean_absolute_error: 0.5993 - val_mean_squared_error: 0.5755
# Epoch 31/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.6569 - mean_absolute_error: 0.6537 - mean_squared_error: 0.6569 - val_loss: 0.5734 - val_mean_absolute_error: 0.5999 - val_mean_squared_error: 0.5734
# Epoch 32/50
# 242/242 [==============================] - 0s 66us/step - loss: 0.6580 - mean_absolute_error: 0.6534 - mean_squared_error: 0.6580 - val_loss: 0.5734 - val_mean_absolute_error: 0.6003 - val_mean_squared_error: 0.5734
# Epoch 33/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6500 - mean_absolute_error: 0.6507 - mean_squared_error: 0.6500 - val_loss: 0.5707 - val_mean_absolute_error: 0.5958 - val_mean_squared_error: 0.5707
# Epoch 34/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6448 - mean_absolute_error: 0.6471 - mean_squared_error: 0.6448 - val_loss: 0.5673 - val_mean_absolute_error: 0.5923 - val_mean_squared_error: 0.5673
# Epoch 35/50
# 242/242 [==============================] - 0s 64us/step - loss: 0.6402 - mean_absolute_error: 0.6435 - mean_squared_error: 0.6402 - val_loss: 0.5614 - val_mean_absolute_error: 0.5914 - val_mean_squared_error: 0.5614
# Epoch 36/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6361 - mean_absolute_error: 0.6406 - mean_squared_error: 0.6361 - val_loss: 0.5626 - val_mean_absolute_error: 0.5925 - val_mean_squared_error: 0.5626
# Epoch 37/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.6319 - mean_absolute_error: 0.6393 - mean_squared_error: 0.6319 - val_loss: 0.5616 - val_mean_absolute_error: 0.5921 - val_mean_squared_error: 0.5616
# Epoch 38/50
# 242/242 [==============================] - 0s 59us/step - loss: 0.6276 - mean_absolute_error: 0.6367 - mean_squared_error: 0.6276 - val_loss: 0.5603 - val_mean_absolute_error: 0.5928 - val_mean_squared_error: 0.5603
# Epoch 39/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.6253 - mean_absolute_error: 0.6351 - mean_squared_error: 0.6253 - val_loss: 0.5612 - val_mean_absolute_error: 0.5927 - val_mean_squared_error: 0.5612
# Epoch 40/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.6203 - mean_absolute_error: 0.6326 - mean_squared_error: 0.6203 - val_loss: 0.5586 - val_mean_absolute_error: 0.5902 - val_mean_squared_error: 0.5586
# Epoch 41/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.6172 - mean_absolute_error: 0.6314 - mean_squared_error: 0.6172 - val_loss: 0.5564 - val_mean_absolute_error: 0.5882 - val_mean_squared_error: 0.5564
# Epoch 42/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.6133 - mean_absolute_error: 0.6295 - mean_squared_error: 0.6133 - val_loss: 0.5554 - val_mean_absolute_error: 0.5854 - val_mean_squared_error: 0.5554
# Epoch 43/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.6104 - mean_absolute_error: 0.6280 - mean_squared_error: 0.6104 - val_loss: 0.5574 - val_mean_absolute_error: 0.5854 - val_mean_squared_error: 0.5574
# Epoch 44/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.6067 - mean_absolute_error: 0.6265 - mean_squared_error: 0.6067 - val_loss: 0.5559 - val_mean_absolute_error: 0.5862 - val_mean_squared_error: 0.5559
# Epoch 45/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.6037 - mean_absolute_error: 0.6248 - mean_squared_error: 0.6037 - val_loss: 0.5582 - val_mean_absolute_error: 0.5853 - val_mean_squared_error: 0.5582
# Epoch 46/50
# 242/242 [==============================] - 0s 61us/step - loss: 0.5998 - mean_absolute_error: 0.6235 - mean_squared_error: 0.5998 - val_loss: 0.5583 - val_mean_absolute_error: 0.5854 - val_mean_squared_error: 0.5583
# Epoch 47/50
# 242/242 [==============================] - 0s 62us/step - loss: 0.5953 - mean_absolute_error: 0.6203 - mean_squared_error: 0.5953 - val_loss: 0.5557 - val_mean_absolute_error: 0.5846 - val_mean_squared_error: 0.5557
# Epoch 48/50
# 242/242 [==============================] - 0s 60us/step - loss: 0.5933 - mean_absolute_error: 0.6169 - mean_squared_error: 0.5933 - val_loss: 0.5575 - val_mean_absolute_error: 0.5872 - val_mean_squared_error: 0.5575
# Epoch 49/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.5898 - mean_absolute_error: 0.6157 - mean_squared_error: 0.5898 - val_loss: 0.5628 - val_mean_absolute_error: 0.5869 - val_mean_squared_error: 0.5628
# Epoch 50/50
# 242/242 [==============================] - 0s 63us/step - loss: 0.5872 - mean_absolute_error: 0.6147 - mean_squared_error: 0.5872 - val_loss: 0.5598 - val_mean_absolute_error: 0.5877 - val_mean_squared_error: 0.5598

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7630454935057608
# 0.7482265147094587

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.988531768321991, p = 0.051056306809186935
# Test k = 0.9856746792793274, p = 0.6953660249710083

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9910375475883484, p_s = 0.061813823878765106
# k_n = 4.313697134523331, p_n = 0.11568913367946512

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('2_SimpleNeuralNetwork.h5')
