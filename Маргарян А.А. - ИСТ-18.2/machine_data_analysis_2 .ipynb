# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287  0.410173  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.457160  0.0  0.707107  1.444548
# 2 -1.529863  0.0  0.577350  0.454038  0.321489  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019  0.418709  0.0  0.707107  1.141680
# 4  0.355054  0.0  0.000000  0.335019  0.689241  0.0  0.707107  0.601134
# 5  0.355054  1.0  0.000000  0.568560  0.281039  0.0  0.707107  0.008368
# 6  0.253797  0.0  0.577350  0.568560  0.565328  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.490983  0.0  0.707107  0.966733
# 8 -0.170168  1.0  0.816497  0.909866  0.304932  1.0  0.707107  0.563348
# 9  0.355054  1.0  0.816497  0.679061  0.191945  0.0  0.707107  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.314559  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
X = dataset.iloc[:, [*range(1,13),12]].values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 13


first_hidden_layer_size = 40
second_hidden_layer_size = 70

output_layer_size = 1


epochs_number = 15
batch_size = 32

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 40)                560
# _________________________________________________________________
# dense_11 (Dense)             (None, 70)                2870
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 71
# =================================================================
# Total params: 3,501
# Trainable params: 3,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/15
# 242/242 [==============================] - 1s 3ms/step - loss: 1.3130 - mean_absolute_error: 0.8580 - mean_squared_error: 1.3130 - val_loss: 0.9773 - val_mean_absolute_error: 0.7945 - val_mean_squared_error: 0.9773
# Epoch 2/15
# 242/242 [==============================] - 0s 422us/step - loss: 1.0431 - mean_absolute_error: 0.8039 - mean_squared_error: 1.0431 - val_loss: 0.8979 - val_mean_absolute_error: 0.7797 - val_mean_squared_error: 0.8979
# Epoch 3/15
# 242/242 [==============================] - 0s 438us/step - loss: 0.9488 - mean_absolute_error: 0.7881 - mean_squared_error: 0.9488 - val_loss: 0.8576 - val_mean_absolute_error: 0.7564 - val_mean_squared_error: 0.8576
# Epoch 4/15
# 242/242 [==============================] - 0s 810us/step - loss: 0.9017 - mean_absolute_error: 0.7745 - mean_squared_error: 0.9017 - val_loss: 0.7907 - val_mean_absolute_error: 0.7163 - val_mean_squared_error: 0.7907
# Epoch 5/15
# 242/242 [==============================] - 0s 827us/step - loss: 0.8554 - mean_absolute_error: 0.7469 - mean_squared_error: 0.8554 - val_loss: 0.7274 - val_mean_absolute_error: 0.6701 - val_mean_squared_error: 0.7274
# Epoch 6/15
# 242/242 [==============================] - 0s 784us/step - loss: 0.8162 - mean_absolute_error: 0.7280 - mean_squared_error: 0.8162 - val_loss: 0.6943 - val_mean_absolute_error: 0.6515 - val_mean_squared_error: 0.6943
# Epoch 7/15
# 242/242 [==============================] - 0s 474us/step - loss: 0.7847 - mean_absolute_error: 0.7163 - mean_squared_error: 0.7847 - val_loss: 0.6708 - val_mean_absolute_error: 0.6429 - val_mean_squared_error: 0.6708
# Epoch 8/15
# 242/242 [==============================] - 0s 480us/step - loss: 0.7488 - mean_absolute_error: 0.7031 - mean_squared_error: 0.7488 - val_loss: 0.6585 - val_mean_absolute_error: 0.6405 - val_mean_squared_error: 0.6585
# Epoch 9/15
# 242/242 [==============================] - 0s 820us/step - loss: 0.7226 - mean_absolute_error: 0.6918 - mean_squared_error: 0.7226 - val_loss: 0.6402 - val_mean_absolute_error: 0.6324 - val_mean_squared_error: 0.6402
# Epoch 10/15
# 242/242 [==============================] - 0s 432us/step - loss: 0.6996 - mean_absolute_error: 0.6817 - mean_squared_error: 0.6996 - val_loss: 0.6269 - val_mean_absolute_error: 0.6233 - val_mean_squared_error: 0.6269
# /srv/conda/envs/notebook/lib/python3.7/site-packages/keras/callbacks/callbacks.py:95: RuntimeWarning: Method (on_train_batch_end) is slow compared to the batch update (0.105161). Check your callbacks.
#   % (hook_name, delta_t_median), RuntimeWarning)
# Epoch 11/15
# 242/242 [==============================] - 0s 438us/step - loss: 0.6781 - mean_absolute_error: 0.6723 - mean_squared_error: 0.6781 - val_loss: 0.6254 - val_mean_absolute_error: 0.6232 - val_mean_squared_error: 0.6254
# Epoch 12/15
# 242/242 [==============================] - 0s 412us/step - loss: 0.6617 - mean_absolute_error: 0.6633 - mean_squared_error: 0.6617 - val_loss: 0.6121 - val_mean_absolute_error: 0.6146 - val_mean_squared_error: 0.6121
# Epoch 13/15
# 242/242 [==============================] - 0s 425us/step - loss: 0.6447 - mean_absolute_error: 0.6510 - mean_squared_error: 0.6447 - val_loss: 0.6032 - val_mean_absolute_error: 0.6070 - val_mean_squared_error: 0.6032
# Epoch 14/15
# 242/242 [==============================] - 0s 381us/step - loss: 0.6343 - mean_absolute_error: 0.6481 - mean_squared_error: 0.6343 - val_loss: 0.5953 - val_mean_absolute_error: 0.6016 - val_mean_squared_error: 0.5953
# Epoch 15/15
# 242/242 [==============================] - 0s 102us/step - loss: 0.6218 - mean_absolute_error: 0.6382 - mean_squared_error: 0.6218 - val_loss: 0.5909 - val_mean_absolute_error: 0.5985 - val_mean_squared_error: 0.5909

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.7823366281926327
# 0.7686712127523515

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9786364436149597, p = 0.001035813009366393
# Test k = 0.9862341284751892, p = 0.72476726770401

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.987788200378418, p_s = 0.0117183867841959
# k_n = 6.2999254043599455, p_n = 0.042853725187762606

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
