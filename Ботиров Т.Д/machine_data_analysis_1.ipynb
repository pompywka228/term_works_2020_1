# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287  0.410173  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.457160  0.0  0.707107  1.444548
# 2 -1.529863  0.0  0.577350  0.454038  0.321489  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019  0.418709  0.0  0.707107  1.141680
# 4  0.355054  0.0  0.000000  0.335019  0.689241  0.0  0.707107  0.601134
# 5  0.355054  1.0  0.000000  0.568560  0.281039  0.0  0.707107  0.008368
# 6  0.253797  0.0  0.577350  0.568560  0.565328  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.490983  0.0  0.707107  0.966733
# 8 -0.170168  1.0  0.816497  0.909866  0.304932  1.0  0.707107  0.563348
# 9  0.355054  1.0  0.816497  0.679061  0.191945  0.0  0.707107  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.314559  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
X = dataset.drop(columns=['age']).values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 12


first_hidden_layer_size = 10
second_hidden_layer_size = 8

output_layer_size = 1


epochs_number = 23
batch_size = 32

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))


model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                130
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 227
# Trainable params: 227
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 242 samples, validate on 61 samples
# Epoch 1/23
# 242/242 [==============================] - 0s 2ms/step - loss: 1.1013 - mean_absolute_error: 0.8656 - mean_squared_error: 1.1013 - val_loss: 0.9103 - val_mean_absolute_error: 0.7788 - val_mean_squared_error: 0.9103
# Epoch 2/23
# 242/242 [==============================] - 0s 152us/step - loss: 1.0728 - mean_absolute_error: 0.8491 - mean_squared_error: 1.0728 - val_loss: 0.8927 - val_mean_absolute_error: 0.7705 - val_mean_squared_error: 0.8927
# Epoch 3/23
# 242/242 [==============================] - 0s 233us/step - loss: 1.0538 - mean_absolute_error: 0.8369 - mean_squared_error: 1.0538 - val_loss: 0.8834 - val_mean_absolute_error: 0.7650 - val_mean_squared_error: 0.8834
# Epoch 4/23
# 242/242 [==============================] - 0s 192us/step - loss: 1.0356 - mean_absolute_error: 0.8253 - mean_squared_error: 1.0356 - val_loss: 0.8685 - val_mean_absolute_error: 0.7584 - val_mean_squared_error: 0.8685
# Epoch 5/23
# 242/242 [==============================] - 0s 243us/step - loss: 1.0203 - mean_absolute_error: 0.8169 - mean_squared_error: 1.0203 - val_loss: 0.8589 - val_mean_absolute_error: 0.7528 - val_mean_squared_error: 0.8589
# Epoch 6/23
# 242/242 [==============================] - 0s 139us/step - loss: 1.0042 - mean_absolute_error: 0.8078 - mean_squared_error: 1.0042 - val_loss: 0.8473 - val_mean_absolute_error: 0.7465 - val_mean_squared_error: 0.8473
# Epoch 7/23
# 242/242 [==============================] - 0s 207us/step - loss: 0.9884 - mean_absolute_error: 0.7981 - mean_squared_error: 0.9884 - val_loss: 0.8397 - val_mean_absolute_error: 0.7410 - val_mean_squared_error: 0.8397
# Epoch 8/23
# 242/242 [==============================] - 0s 79us/step - loss: 0.9755 - mean_absolute_error: 0.7902 - mean_squared_error: 0.9755 - val_loss: 0.8339 - val_mean_absolute_error: 0.7361 - val_mean_squared_error: 0.8339
# Epoch 9/23
# 242/242 [==============================] - 0s 86us/step - loss: 0.9656 - mean_absolute_error: 0.7829 - mean_squared_error: 0.9656 - val_loss: 0.8301 - val_mean_absolute_error: 0.7320 - val_mean_squared_error: 0.8301
# Epoch 10/23
# 242/242 [==============================] - 0s 235us/step - loss: 0.9549 - mean_absolute_error: 0.7772 - mean_squared_error: 0.9549 - val_loss: 0.8275 - val_mean_absolute_error: 0.7289 - val_mean_squared_error: 0.8275
# Epoch 11/23
# 242/242 [==============================] - 0s 74us/step - loss: 0.9474 - mean_absolute_error: 0.7728 - mean_squared_error: 0.9474 - val_loss: 0.8268 - val_mean_absolute_error: 0.7272 - val_mean_squared_error: 0.8268
# Epoch 12/23
# 242/242 [==============================] - 0s 275us/step - loss: 0.9392 - mean_absolute_error: 0.7694 - mean_squared_error: 0.9392 - val_loss: 0.8210 - val_mean_absolute_error: 0.7244 - val_mean_squared_error: 0.8210
# Epoch 13/23
# 242/242 [==============================] - 0s 80us/step - loss: 0.9322 - mean_absolute_error: 0.7668 - mean_squared_error: 0.9322 - val_loss: 0.8191 - val_mean_absolute_error: 0.7225 - val_mean_squared_error: 0.8191
# Epoch 14/23
# 242/242 [==============================] - 0s 76us/step - loss: 0.9253 - mean_absolute_error: 0.7635 - mean_squared_error: 0.9253 - val_loss: 0.8158 - val_mean_absolute_error: 0.7207 - val_mean_squared_error: 0.8158
# Epoch 15/23
# 242/242 [==============================] - 0s 196us/step - loss: 0.9181 - mean_absolute_error: 0.7612 - mean_squared_error: 0.9181 - val_loss: 0.8101 - val_mean_absolute_error: 0.7180 - val_mean_squared_error: 0.8101
# Epoch 16/23
# 242/242 [==============================] - 0s 88us/step - loss: 0.9126 - mean_absolute_error: 0.7603 - mean_squared_error: 0.9126 - val_loss: 0.8046 - val_mean_absolute_error: 0.7154 - val_mean_squared_error: 0.8046
# Epoch 17/23
# 242/242 [==============================] - 0s 72us/step - loss: 0.9058 - mean_absolute_error: 0.7578 - mean_squared_error: 0.9058 - val_loss: 0.8025 - val_mean_absolute_error: 0.7139 - val_mean_squared_error: 0.8025
# Epoch 18/23
# 242/242 [==============================] - 0s 200us/step - loss: 0.8989 - mean_absolute_error: 0.7543 - mean_squared_error: 0.8989 - val_loss: 0.8016 - val_mean_absolute_error: 0.7137 - val_mean_squared_error: 0.8016
# Epoch 19/23
# 242/242 [==============================] - 0s 72us/step - loss: 0.8922 - mean_absolute_error: 0.7519 - mean_squared_error: 0.8922 - val_loss: 0.7986 - val_mean_absolute_error: 0.7133 - val_mean_squared_error: 0.7986
# Epoch 20/23
# 242/242 [==============================] - 0s 68us/step - loss: 0.8856 - mean_absolute_error: 0.7497 - mean_squared_error: 0.8856 - val_loss: 0.7962 - val_mean_absolute_error: 0.7130 - val_mean_squared_error: 0.7962
# Epoch 21/23
# 242/242 [==============================] - 0s 227us/step - loss: 0.8798 - mean_absolute_error: 0.7482 - mean_squared_error: 0.8798 - val_loss: 0.7919 - val_mean_absolute_error: 0.7122 - val_mean_squared_error: 0.7919
# Epoch 22/23
# 242/242 [==============================] - 0s 77us/step - loss: 0.8726 - mean_absolute_error: 0.7456 - mean_squared_error: 0.8726 - val_loss: 0.7932 - val_mean_absolute_error: 0.7134 - val_mean_squared_error: 0.7932
# Epoch 23/23
# 242/242 [==============================] - 0s 68us/step - loss: 0.8663 - mean_absolute_error: 0.7436 - mean_squared_error: 0.8663 - val_loss: 0.7873 - val_mean_absolute_error: 0.7116 - val_mean_squared_error: 0.7873

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.9281238441017294
# 0.8872898210693362

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9697595238685608, p = 5.075442822999321e-05
# Test k = 0.966803252696991, p = 0.09643787145614624

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9737095236778259, p_s = 2.38058710237965e-05
# k_n = 13.956313151509764, p_n = 0.0009320197283409817

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
