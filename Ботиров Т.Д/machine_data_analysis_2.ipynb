# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287  0.410173  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.457160  0.0  0.707107  1.444548
# 2 -1.529863  0.0  0.577350  0.454038  0.321489  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019  0.418709  0.0  0.707107  1.141680
# 4  0.355054  0.0  0.000000  0.335019  0.689241  0.0  0.707107  0.601134
# 5  0.355054  1.0  0.000000  0.568560  0.281039  0.0  0.707107  0.008368
# 6  0.253797  0.0  0.577350  0.568560  0.565328  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.490983  0.0  0.707107  0.966733
# 8 -0.170168  1.0  0.816497  0.909866  0.304932  1.0  0.707107  0.563348
# 9  0.355054  1.0  0.816497  0.679061  0.191945  0.0  0.707107  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.314559  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
X = dataset.drop(columns=['age']).values
Y = dataset['age'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 12


first_hidden_layer_size = 10
second_hidden_layer_size = 8

output_layer_size = 1


epochs_number = 23
batch_size = 32

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))


model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                130
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 227
# Trainable params: 227
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 212 samples, validate on 91 samples
# Epoch 1/23
# 212/212 [==============================] - 0s 2ms/step - loss: 1.9067 - mean_absolute_error: 1.1786 - mean_squared_error: 1.9067 - val_loss: 1.4951 - val_mean_absolute_error: 1.0507 - val_mean_squared_error: 1.4951
# Epoch 2/23
# 212/212 [==============================] - 0s 182us/step - loss: 1.6778 - mean_absolute_error: 1.1019 - mean_squared_error: 1.6778 - val_loss: 1.3265 - val_mean_absolute_error: 0.9906 - val_mean_squared_error: 1.3265
# Epoch 3/23
# 212/212 [==============================] - 0s 165us/step - loss: 1.4942 - mean_absolute_error: 1.0384 - mean_squared_error: 1.4942 - val_loss: 1.2131 - val_mean_absolute_error: 0.9451 - val_mean_squared_error: 1.2131
# Epoch 4/23
# 212/212 [==============================] - 0s 169us/step - loss: 1.3766 - mean_absolute_error: 0.9935 - mean_squared_error: 1.3766 - val_loss: 1.1333 - val_mean_absolute_error: 0.9119 - val_mean_squared_error: 1.1333
# Epoch 5/23
# 212/212 [==============================] - 0s 173us/step - loss: 1.3005 - mean_absolute_error: 0.9596 - mean_squared_error: 1.3005 - val_loss: 1.0796 - val_mean_absolute_error: 0.8873 - val_mean_squared_error: 1.0796
# Epoch 6/23
# 212/212 [==============================] - 0s 180us/step - loss: 1.2414 - mean_absolute_error: 0.9342 - mean_squared_error: 1.2414 - val_loss: 1.0430 - val_mean_absolute_error: 0.8692 - val_mean_squared_error: 1.0430
# Epoch 7/23
# 212/212 [==============================] - 0s 146us/step - loss: 1.2051 - mean_absolute_error: 0.9140 - mean_squared_error: 1.2051 - val_loss: 1.0131 - val_mean_absolute_error: 0.8535 - val_mean_squared_error: 1.0131
# Epoch 8/23
# 212/212 [==============================] - 0s 429us/step - loss: 1.1735 - mean_absolute_error: 0.8977 - mean_squared_error: 1.1735 - val_loss: 0.9904 - val_mean_absolute_error: 0.8406 - val_mean_squared_error: 0.9904
# Epoch 9/23
# 212/212 [==============================] - 0s 450us/step - loss: 1.1425 - mean_absolute_error: 0.8813 - mean_squared_error: 1.1425 - val_loss: 0.9748 - val_mean_absolute_error: 0.8309 - val_mean_squared_error: 0.9748
# Epoch 10/23
# 212/212 [==============================] - 0s 432us/step - loss: 1.1204 - mean_absolute_error: 0.8702 - mean_squared_error: 1.1204 - val_loss: 0.9627 - val_mean_absolute_error: 0.8224 - val_mean_squared_error: 0.9627
# Epoch 11/23
# 212/212 [==============================] - ETA: 0s - loss: 1.1103 - mean_absolute_error: 0.8582 - mean_squared_error: 1.11 - 0s 482us/step - loss: 1.0975 - mean_absolute_error: 0.8581 - mean_squared_error: 1.0975 - val_loss: 0.9536 - val_mean_absolute_error: 0.8157 - val_mean_squared_error: 0.9536
# Epoch 12/23
# 212/212 [==============================] - 0s 484us/step - loss: 1.0799 - mean_absolute_error: 0.8477 - mean_squared_error: 1.0799 - val_loss: 0.9455 - val_mean_absolute_error: 0.8092 - val_mean_squared_error: 0.9455
# Epoch 13/23
# 212/212 [==============================] - 0s 454us/step - loss: 1.0627 - mean_absolute_error: 0.8370 - mean_squared_error: 1.0627 - val_loss: 0.9378 - val_mean_absolute_error: 0.8028 - val_mean_squared_error: 0.9378
# Epoch 14/23
# 212/212 [==============================] - 0s 459us/step - loss: 1.0476 - mean_absolute_error: 0.8280 - mean_squared_error: 1.0476 - val_loss: 0.9316 - val_mean_absolute_error: 0.7963 - val_mean_squared_error: 0.9316
# Epoch 15/23
# 212/212 [==============================] - 0s 409us/step - loss: 1.0329 - mean_absolute_error: 0.8188 - mean_squared_error: 1.0329 - val_loss: 0.9272 - val_mean_absolute_error: 0.7916 - val_mean_squared_error: 0.9272
# Epoch 16/23
# 212/212 [==============================] - 0s 418us/step - loss: 1.0189 - mean_absolute_error: 0.8103 - mean_squared_error: 1.0189 - val_loss: 0.9234 - val_mean_absolute_error: 0.7863 - val_mean_squared_error: 0.9234
# Epoch 17/23
# 212/212 [==============================] - 0s 97us/step - loss: 1.0060 - mean_absolute_error: 0.8017 - mean_squared_error: 1.0060 - val_loss: 0.9187 - val_mean_absolute_error: 0.7804 - val_mean_squared_error: 0.9187
# Epoch 18/23
# 212/212 [==============================] - 0s 81us/step - loss: 0.9921 - mean_absolute_error: 0.7932 - mean_squared_error: 0.9921 - val_loss: 0.9142 - val_mean_absolute_error: 0.7755 - val_mean_squared_error: 0.9142
# Epoch 19/23
# 212/212 [==============================] - 0s 404us/step - loss: 0.9778 - mean_absolute_error: 0.7866 - mean_squared_error: 0.9778 - val_loss: 0.9103 - val_mean_absolute_error: 0.7716 - val_mean_squared_error: 0.9103
# Epoch 20/23
# 212/212 [==============================] - 0s 83us/step - loss: 0.9667 - mean_absolute_error: 0.7813 - mean_squared_error: 0.9667 - val_loss: 0.9084 - val_mean_absolute_error: 0.7683 - val_mean_squared_error: 0.9084
# Epoch 21/23
# 212/212 [==============================] - 0s 371us/step - loss: 0.9534 - mean_absolute_error: 0.7743 - mean_squared_error: 0.9534 - val_loss: 0.9060 - val_mean_absolute_error: 0.7650 - val_mean_squared_error: 0.9060
# Epoch 22/23
# 212/212 [==============================] - 0s 95us/step - loss: 0.9438 - mean_absolute_error: 0.7692 - mean_squared_error: 0.9438 - val_loss: 0.9034 - val_mean_absolute_error: 0.7617 - val_mean_squared_error: 0.9034
# Epoch 23/23
# 212/212 [==============================] - 0s 391us/step - loss: 0.9308 - mean_absolute_error: 0.7631 - mean_squared_error: 0.9308 - val_loss: 0.8997 - val_mean_absolute_error: 0.7595 - val_mean_squared_error: 0.8997

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.9605583037376034
# 0.9485126076298703

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9752819538116455, p = 0.0008781951037235558
# Test k = 0.9750591516494751, p = 0.07766181230545044

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9768779277801514, p_s = 8.311898272950202e-05
# k_n = 13.18888214514896, p_n = 0.00136795128256707

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('SimpleNeuralNetwork.h5')
