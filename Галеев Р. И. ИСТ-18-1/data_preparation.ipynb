# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Загрузка и анализ набора данных
water_dataset = pd.read_csv('Набор_5_токсичность_воды.csv',  sep=';')
water_dataset.head(10)
# Out:
#      tpsa    saacc  h-050  mlogp  rdchi  gats1p  nn  c-040   lc50
# 0    0.00    0.000      0  2.419  1.225   0.667   0      0  3.740
# 1    0.00    0.000      0  2.638  1.401   0.632   0      0  4.330
# 2    9.23   11.000      0  5.799  2.930   0.486   0      0  7.019
# 3    9.23   11.000      0  5.453  2.887   0.495   0      0  6.723
# 4    9.23   11.000      0  4.068  2.758   0.695   0      0  5.979
# 5  215.34  327.629      3  0.189  4.677   1.333   0      4  6.064
# 6    9.23   11.000      0  2.723  2.321   1.165   0      0  7.337
# 7    0.00    0.000      0  3.267  2.318   0.963   0      0  4.100
# 8    0.00    0.000      0  2.067  1.800   1.250   0      0  3.941
# 9    0.00    0.000      0  2.746  1.667   1.400   0      0  3.809

# %%
for i in water_dataset:
    if i not in ['mlogp', 'rdchi', 'gats1p', 'lc50']:
        water_dataset[i] = water_dataset[i].replace(0, water_dataset[i].mean())
water_dataset.head(10)
# Out:
#         tpsa       saacc     h-050  mlogp  rdchi  gats1p        nn    c-040  \
# 0   48.47293   58.869018  0.937729  2.419  1.225   0.667  1.003663  0.35348
# 1   48.47293   58.869018  0.937729  2.638  1.401   0.632  1.003663  0.35348
# 2    9.23000   11.000000  0.937729  5.799  2.930   0.486  1.003663  0.35348
# 3    9.23000   11.000000  0.937729  5.453  2.887   0.495  1.003663  0.35348
# 4    9.23000   11.000000  0.937729  4.068  2.758   0.695  1.003663  0.35348
# 5  215.34000  327.629000  3.000000  0.189  4.677   1.333  1.003663  4.00000
# 6    9.23000   11.000000  0.937729  2.723  2.321   1.165  1.003663  0.35348
# 7   48.47293   58.869018  0.937729  3.267  2.318   0.963  1.003663  0.35348
# 8   48.47293   58.869018  0.937729  2.067  1.800   1.250  1.003663  0.35348
# 9   48.47293   58.869018  0.937729  2.746  1.667   1.400  1.003663  0.35348
#
#     lc50
# 0  3.740
# 1  4.330
# 2  7.019
# 3  6.723
# 4  5.979
# 5  6.064
# 6  7.337
# 7  4.100
# 8  3.941
# 9  3.809

# %%
# Создаем набор данных, в котором будут храниться обработанные данные
dataset = pd.DataFrame()

# %%
# обработка колонки "tpsa"
data = water_dataset['tpsa']

plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 140)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['tpsa'] = MinMaxScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa
# 0  0.514570
# 1  0.514570
# 2  0.123412
# 3  0.123412
# 4  0.123412
# 5  1.000000
# 6  0.123412
# 7  0.514570
# 8  0.514570
# 9  0.514570

# %%
data = water_dataset['saacc']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 260)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['saacc'] = MinMaxScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc
# 0  0.514570  0.411306
# 1  0.514570  0.411306
# 2  0.123412  0.107901
# 3  0.123412  0.107901
# 4  0.123412  0.107901
# 5  1.000000  1.000000
# 6  0.123412  0.107901
# 7  0.514570  0.411306
# 8  0.514570  0.411306
# 9  0.514570  0.411306

# %%
data = water_dataset['h-050']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 9)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['h-050'] = MinMaxScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050
# 0  0.514570  0.411306  0.000000
# 1  0.514570  0.411306  0.000000
# 2  0.123412  0.107901  0.000000
# 3  0.123412  0.107901  0.000000
# 4  0.123412  0.107901  0.000000
# 5  1.000000  1.000000  0.375897
# 6  0.123412  0.107901  0.000000
# 7  0.514570  0.411306  0.000000
# 8  0.514570  0.411306  0.000000
# 9  0.514570  0.411306  0.000000

# %%
data = water_dataset['mlogp']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, -1.5, 7)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data**0.5, bins = 50)
plt.show()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['mlogp'] = StandardScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp
# 0  0.514570  0.411306  0.000000  0.019635
# 1  0.514570  0.411306  0.000000  0.159062
# 2  0.123412  0.107901  0.000000  1.745911
# 3  0.123412  0.107901  0.000000  1.598251
# 4  0.123412  0.107901  0.000000  0.954059
# 5  1.000000  1.000000  0.375897 -2.248683
# 6  0.123412  0.107901  0.000000  0.211611
# 7  0.514570  0.411306  0.000000  0.530092
# 8  0.514570  0.411306  0.000000 -0.218431
# 9  0.514570  0.411306  0.000000  0.225688

# %%
data = water_dataset['rdchi']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 1, 4.5)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['rdchi'] = StandardScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684
# 2  0.123412  0.107901  0.000000  1.745911  0.652219
# 3  0.123412  0.107901  0.000000  1.598251  0.599535
# 4  0.123412  0.107901  0.000000  0.954059  0.439081
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498

# %%
data = water_dataset['gats1p']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0.30, 2)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['gats1p'] = StandardScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043

# %%
data = water_dataset['nn']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 6)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['nn'] = MinMaxScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p        nn
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340  0.001262
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755  0.001262
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754  0.001262
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789  0.001262
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297  0.001262
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006  0.001262
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174  0.001262
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742  0.001262
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631  0.001262
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043  0.001262

# %%
data = water_dataset['c-040']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 5)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['c-040'] = MinMaxScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p        nn  \
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340  0.001262
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755  0.001262
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754  0.001262
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789  0.001262
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297  0.001262
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006  0.001262
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174  0.001262
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742  0.001262
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631  0.001262
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043  0.001262
#
#      c-040
# 0  0.00000
# 1  0.00000
# 2  0.00000
# 3  0.00000
# 4  0.00000
# 5  0.85619
# 6  0.00000
# 7  0.00000
# 8  0.00000
# 9  0.00000

# %%
data = water_dataset['lc50']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 9)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data**0.5).reshape(-1, 1)
dataset['lc50'] = StandardScaler().fit_transform(data).flatten() 
dataset.head(10)
# Out:
#        tpsa     saacc     h-050     mlogp     rdchi    gats1p        nn  \
# 0  0.514570  0.411306  0.000000  0.019635 -1.875809 -0.955340  0.001262
# 1  0.514570  0.411306  0.000000  0.159062 -1.554684 -1.066755  0.001262
# 2  0.123412  0.107901  0.000000  1.745911  0.652219 -1.568754  0.001262
# 3  0.123412  0.107901  0.000000  1.598251  0.599535 -1.535789  0.001262
# 4  0.123412  0.107901  0.000000  0.954059  0.439081 -0.868297  0.001262
# 5  1.000000  1.000000  0.375897 -2.248683  2.363947  0.778006  0.001262
# 6  0.123412  0.107901  0.000000  0.211611 -0.134453  0.392174  0.001262
# 7  0.514570  0.411306  0.000000  0.530092 -0.138569 -0.110742  0.001262
# 8  0.514570  0.411306  0.000000 -0.218431 -0.894383  0.590631  0.001262
# 9  0.514570  0.411306  0.000000  0.225688 -1.105498  0.925043  0.001262
#
#      c-040      lc50
# 0  0.00000 -0.455071
# 1  0.00000 -0.093061
# 2  0.00000  1.307301
# 3  0.00000  1.168207
# 4  0.00000  0.804428
# 5  0.85619  0.847093
# 6  0.00000  1.453502
# 7  0.00000 -0.231058
# 8  0.00000 -0.328732
# 9  0.00000 -0.411327

# %%
dataset.to_csv('prepared_data.csv', index=False)
