# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tpsa</th>
#       <th>saacc</th>
#       <th>h-050</th>
#       <th>mlogp</th>
#       <th>rdchi</th>
#       <th>gats1p</th>
#       <th>nn</th>
#       <th>c-040</th>
#       <th>lc50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.019635</td>
#       <td>-1.875809</td>
#       <td>-0.955340</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.455071</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.159062</td>
#       <td>-1.554684</td>
#       <td>-1.066755</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.093061</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>1.745911</td>
#       <td>0.652219</td>
#       <td>-1.568754</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.307301</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>1.598251</td>
#       <td>0.599535</td>
#       <td>-1.535789</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.168207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>0.954059</td>
#       <td>0.439081</td>
#       <td>-0.868297</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>0.804428</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.375897</td>
#       <td>-2.248683</td>
#       <td>2.363947</td>
#       <td>0.778006</td>
#       <td>0.001262</td>
#       <td>0.85619</td>
#       <td>0.847093</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>0.211611</td>
#       <td>-0.134453</td>
#       <td>0.392174</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.453502</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.530092</td>
#       <td>-0.138569</td>
#       <td>-0.110742</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.231058</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>-0.218431</td>
#       <td>-0.894383</td>
#       <td>0.590631</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.328732</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.225688</td>
#       <td>-1.105498</td>
#       <td>0.925043</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.411327</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.drop(columns=['mlogp', 'c-040']).values
Y = dataset['lc50'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.


input_layer_size = 7


first_hidden_layer_size = 8
second_hidden_layer_size = 8

output_layer_size = 1


epochs_number = 50
batch_size = 4

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 8)                 64
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 436 samples, validate on 110 samples
# Epoch 1/50
# 436/436 [==============================] - 0s 629us/step - loss: 0.7310 - mean_absolute_error: 0.6500 - mean_squared_error: 0.7310 - val_loss: 0.5763 - val_mean_absolute_error: 0.5829 - val_mean_squared_error: 0.5763
# Epoch 2/50
# 436/436 [==============================] - 0s 302us/step - loss: 0.4241 - mean_absolute_error: 0.4855 - mean_squared_error: 0.4241 - val_loss: 0.3211 - val_mean_absolute_error: 0.4280 - val_mean_squared_error: 0.3211
# Epoch 3/50
# 436/436 [==============================] - 0s 303us/step - loss: 0.2388 - mean_absolute_error: 0.3533 - mean_squared_error: 0.2388 - val_loss: 0.1646 - val_mean_absolute_error: 0.2954 - val_mean_squared_error: 0.1646
# Epoch 4/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.1144 - mean_absolute_error: 0.2221 - mean_squared_error: 0.1144 - val_loss: 0.0678 - val_mean_absolute_error: 0.1781 - val_mean_squared_error: 0.0678
# Epoch 5/50
# 436/436 [==============================] - 0s 302us/step - loss: 0.0512 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0512 - val_loss: 0.0334 - val_mean_absolute_error: 0.1223 - val_mean_squared_error: 0.0334
# Epoch 6/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0317 - mean_absolute_error: 0.1139 - mean_squared_error: 0.0317 - val_loss: 0.0253 - val_mean_absolute_error: 0.1162 - val_mean_squared_error: 0.0253
# Epoch 7/50
# 436/436 [==============================] - 0s 300us/step - loss: 0.0248 - mean_absolute_error: 0.1056 - mean_squared_error: 0.0248 - val_loss: 0.0213 - val_mean_absolute_error: 0.1075 - val_mean_squared_error: 0.0213
# Epoch 8/50
# 436/436 [==============================] - 0s 300us/step - loss: 0.0209 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0209 - val_loss: 0.0172 - val_mean_absolute_error: 0.0966 - val_mean_squared_error: 0.0172
# Epoch 9/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.0184 - mean_absolute_error: 0.0949 - mean_squared_error: 0.0184 - val_loss: 0.0151 - val_mean_absolute_error: 0.0918 - val_mean_squared_error: 0.0151
# Epoch 10/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.0161 - mean_absolute_error: 0.0890 - mean_squared_error: 0.0161 - val_loss: 0.0154 - val_mean_absolute_error: 0.0898 - val_mean_squared_error: 0.0154
# Epoch 11/50
# 436/436 [==============================] - 0s 302us/step - loss: 0.0142 - mean_absolute_error: 0.0836 - mean_squared_error: 0.0142 - val_loss: 0.0109 - val_mean_absolute_error: 0.0804 - val_mean_squared_error: 0.0109
# Epoch 12/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.0122 - mean_absolute_error: 0.0798 - mean_squared_error: 0.0122 - val_loss: 0.0145 - val_mean_absolute_error: 0.0878 - val_mean_squared_error: 0.0145
# Epoch 13/50
# 436/436 [==============================] - 0s 298us/step - loss: 0.0112 - mean_absolute_error: 0.0774 - mean_squared_error: 0.0112 - val_loss: 0.0111 - val_mean_absolute_error: 0.0808 - val_mean_squared_error: 0.0111
# Epoch 14/50
# 436/436 [==============================] - 0s 301us/step - loss: 0.0102 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0102 - val_loss: 0.0090 - val_mean_absolute_error: 0.0712 - val_mean_squared_error: 0.0090
# Epoch 15/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.0088 - mean_absolute_error: 0.0685 - mean_squared_error: 0.0088 - val_loss: 0.0069 - val_mean_absolute_error: 0.0657 - val_mean_squared_error: 0.0069
# Epoch 16/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0078 - mean_absolute_error: 0.0658 - mean_squared_error: 0.0078 - val_loss: 0.0077 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0077
# Epoch 17/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0072 - mean_absolute_error: 0.0637 - mean_squared_error: 0.0072 - val_loss: 0.0059 - val_mean_absolute_error: 0.0584 - val_mean_squared_error: 0.0059
# Epoch 18/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0065 - mean_absolute_error: 0.0594 - mean_squared_error: 0.0065 - val_loss: 0.0057 - val_mean_absolute_error: 0.0581 - val_mean_squared_error: 0.0057
# Epoch 19/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0058 - mean_absolute_error: 0.0570 - mean_squared_error: 0.0058 - val_loss: 0.0054 - val_mean_absolute_error: 0.0558 - val_mean_squared_error: 0.0054
# Epoch 20/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0056 - mean_absolute_error: 0.0556 - mean_squared_error: 0.0056 - val_loss: 0.0040 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0040
# Epoch 21/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0052 - mean_absolute_error: 0.0526 - mean_squared_error: 0.0052 - val_loss: 0.0040 - val_mean_absolute_error: 0.0489 - val_mean_squared_error: 0.0040
# Epoch 22/50
# 436/436 [==============================] - 0s 309us/step - loss: 0.0047 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0047 - val_loss: 0.0037 - val_mean_absolute_error: 0.0471 - val_mean_squared_error: 0.0037
# Epoch 23/50
# 436/436 [==============================] - 0s 310us/step - loss: 0.0043 - mean_absolute_error: 0.0479 - mean_squared_error: 0.0043 - val_loss: 0.0042 - val_mean_absolute_error: 0.0502 - val_mean_squared_error: 0.0042
# Epoch 24/50
# 436/436 [==============================] - 0s 312us/step - loss: 0.0042 - mean_absolute_error: 0.0481 - mean_squared_error: 0.0042 - val_loss: 0.0031 - val_mean_absolute_error: 0.0436 - val_mean_squared_error: 0.0031
# Epoch 25/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.0039 - mean_absolute_error: 0.0453 - mean_squared_error: 0.0039 - val_loss: 0.0026 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0026
# Epoch 26/50
# 436/436 [==============================] - 0s 309us/step - loss: 0.0036 - mean_absolute_error: 0.0429 - mean_squared_error: 0.0036 - val_loss: 0.0024 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0024
# Epoch 27/50
# 436/436 [==============================] - 0s 305us/step - loss: 0.0034 - mean_absolute_error: 0.0430 - mean_squared_error: 0.0034 - val_loss: 0.0028 - val_mean_absolute_error: 0.0403 - val_mean_squared_error: 0.0028
# Epoch 28/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.0032 - mean_absolute_error: 0.0408 - mean_squared_error: 0.0032 - val_loss: 0.0026 - val_mean_absolute_error: 0.0390 - val_mean_squared_error: 0.0026
# Epoch 29/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.0029 - mean_absolute_error: 0.0389 - mean_squared_error: 0.0029 - val_loss: 0.0024 - val_mean_absolute_error: 0.0368 - val_mean_squared_error: 0.0024
# Epoch 30/50
# 436/436 [==============================] - 0s 308us/step - loss: 0.0027 - mean_absolute_error: 0.0373 - mean_squared_error: 0.0027 - val_loss: 0.0018 - val_mean_absolute_error: 0.0308 - val_mean_squared_error: 0.0018
# Epoch 31/50
# 436/436 [==============================] - 0s 312us/step - loss: 0.0027 - mean_absolute_error: 0.0364 - mean_squared_error: 0.0027 - val_loss: 0.0018 - val_mean_absolute_error: 0.0324 - val_mean_squared_error: 0.0018
# Epoch 32/50
# 436/436 [==============================] - 0s 308us/step - loss: 0.0023 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411 - val_mean_squared_error: 0.0028
# Epoch 33/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0023 - mean_absolute_error: 0.0344 - mean_squared_error: 0.0023 - val_loss: 0.0020 - val_mean_absolute_error: 0.0348 - val_mean_squared_error: 0.0020
# Epoch 34/50
# 436/436 [==============================] - 0s 312us/step - loss: 0.0022 - mean_absolute_error: 0.0340 - mean_squared_error: 0.0022 - val_loss: 0.0017 - val_mean_absolute_error: 0.0312 - val_mean_squared_error: 0.0017
# Epoch 35/50
# 436/436 [==============================] - 0s 308us/step - loss: 0.0019 - mean_absolute_error: 0.0311 - mean_squared_error: 0.0019 - val_loss: 0.0017 - val_mean_absolute_error: 0.0303 - val_mean_squared_error: 0.0017
# Epoch 36/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0017 - mean_absolute_error: 0.0297 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292 - val_mean_squared_error: 0.0015
# Epoch 37/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0018 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0018 - val_loss: 0.0020 - val_mean_absolute_error: 0.0323 - val_mean_squared_error: 0.0020
# Epoch 38/50
# 436/436 [==============================] - 0s 317us/step - loss: 0.0016 - mean_absolute_error: 0.0287 - mean_squared_error: 0.0016 - val_loss: 0.0017 - val_mean_absolute_error: 0.0313 - val_mean_squared_error: 0.0017
# Epoch 39/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0015 - mean_absolute_error: 0.0270 - mean_squared_error: 0.0015 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270 - val_mean_squared_error: 0.0013
# Epoch 40/50
# 436/436 [==============================] - 0s 310us/step - loss: 0.0013 - mean_absolute_error: 0.0266 - mean_squared_error: 0.0013 - val_loss: 0.0015 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0015
# Epoch 41/50
# 436/436 [==============================] - 0s 307us/step - loss: 0.0014 - mean_absolute_error: 0.0265 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0013
# Epoch 42/50
# 436/436 [==============================] - 0s 308us/step - loss: 0.0013 - mean_absolute_error: 0.0256 - mean_squared_error: 0.0013 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285 - val_mean_squared_error: 0.0014
# Epoch 43/50
# 436/436 [==============================] - 0s 304us/step - loss: 0.0012 - mean_absolute_error: 0.0246 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0012
# Epoch 44/50
# 436/436 [==============================] - 0s 306us/step - loss: 0.0011 - mean_absolute_error: 0.0231 - mean_squared_error: 0.0011 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242 - val_mean_squared_error: 0.0011
# Epoch 45/50
# 436/436 [==============================] - 0s 312us/step - loss: 0.0011 - mean_absolute_error: 0.0234 - mean_squared_error: 0.0011 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300 - val_mean_squared_error: 0.0014
# Epoch 46/50
# 436/436 [==============================] - 0s 311us/step - loss: 8.7836e-04 - mean_absolute_error: 0.0208 - mean_squared_error: 8.7836e-04 - val_loss: 0.0010 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 0.0010
# Epoch 47/50
# 436/436 [==============================] - 0s 310us/step - loss: 9.6228e-04 - mean_absolute_error: 0.0218 - mean_squared_error: 9.6228e-04 - val_loss: 9.5754e-04 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.5754e-04
# Epoch 48/50
# 436/436 [==============================] - 0s 303us/step - loss: 9.4336e-04 - mean_absolute_error: 0.0229 - mean_squared_error: 9.4336e-04 - val_loss: 9.3587e-04 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 9.3587e-04
# Epoch 49/50
# 436/436 [==============================] - 0s 310us/step - loss: 8.9984e-04 - mean_absolute_error: 0.0217 - mean_squared_error: 8.9984e-04 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261 - val_mean_squared_error: 0.0012
# Epoch 50/50
# 436/436 [==============================] - 0s 308us/step - loss: 7.5788e-04 - mean_absolute_error: 0.0199 - mean_squared_error: 7.5788e-04 - val_loss: 9.2734e-04 - val_mean_absolute_error: 0.0222 - val_mean_squared_error: 9.2734e-04

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 0.02576230331470949
# 0.03045223471305621

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.9438202381134033, p = 8.659141979838747e-12
# Test k = 0.9477748274803162, p = 0.000294367375317961

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9502924680709839, p_s = 1.3830880885024044e-12
# k_n = 54.978492107669055, p_n = 1.1523174195155112e-12

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('2_SimpleNeuralNetwork.h5')
