# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
# Out:
# Using TensorFlow backend.

# %%
# Загрузка подготовленного набора данных
dataset = pd.read_csv('prepared_data.csv')
dataset.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tpsa</th>
#       <th>saacc</th>
#       <th>h-050</th>
#       <th>mlogp</th>
#       <th>rdchi</th>
#       <th>gats1p</th>
#       <th>nn</th>
#       <th>c-040</th>
#       <th>lc50</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.019635</td>
#       <td>-1.875809</td>
#       <td>-0.955340</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.455071</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.159062</td>
#       <td>-1.554684</td>
#       <td>-1.066755</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.093061</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>1.745911</td>
#       <td>0.652219</td>
#       <td>-1.568754</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.307301</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>1.598251</td>
#       <td>0.599535</td>
#       <td>-1.535789</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.168207</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>0.954059</td>
#       <td>0.439081</td>
#       <td>-0.868297</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>0.804428</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>0.375897</td>
#       <td>-2.248683</td>
#       <td>2.363947</td>
#       <td>0.778006</td>
#       <td>0.001262</td>
#       <td>0.85619</td>
#       <td>0.847093</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.123412</td>
#       <td>0.107901</td>
#       <td>0.000000</td>
#       <td>0.211611</td>
#       <td>-0.134453</td>
#       <td>0.392174</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>1.453502</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.530092</td>
#       <td>-0.138569</td>
#       <td>-0.110742</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.231058</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>-0.218431</td>
#       <td>-0.894383</td>
#       <td>0.590631</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.328732</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.514570</td>
#       <td>0.411306</td>
#       <td>0.000000</td>
#       <td>0.225688</td>
#       <td>-1.105498</td>
#       <td>0.925043</td>
#       <td>0.001262</td>
#       <td>0.00000</td>
#       <td>-0.411327</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
X = dataset.drop(columns=['mlogp', 'c-040']).values
Y = dataset['lc50'].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %%
# Задаем параметры структуры нейронной сети.
input_layer_size = 7
first_hidden_layer_size = 2
second_hidden_layer_size = 2

output_layer_size = 1

epochs_number = 50
batch_size = 4

# %%
# Создание нейронной сети прямого распространения, пока она пустая, т.е. не содержит слоёв и нейронов.
model = Sequential()

# Входной слой и первый скрытый слой, функция активации - ReLU
model.add(Dense(first_hidden_layer_size, input_dim=input_layer_size, activation='relu'))

model.add(Dense(second_hidden_layer_size, activation='relu'))

model.add(Dense(output_layer_size, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 2)                 16
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Настройка нейронной сети.
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
# Обучение нейронной сети.
history = model.fit(X_train, Y_train, validation_data = (X_test,Y_test), epochs=epochs_number, batch_size=batch_size)
# Out:
# Train on 436 samples, validate on 110 samples
# Epoch 1/50
# 436/436 [==============================] - 0s 613us/step - loss: 1.7554 - mean_absolute_error: 0.9845 - mean_squared_error: 1.7554 - val_loss: 0.7927 - val_mean_absolute_error: 0.6876 - val_mean_squared_error: 0.7927
# Epoch 2/50
# 436/436 [==============================] - 0s 288us/step - loss: 1.4323 - mean_absolute_error: 0.8899 - mean_squared_error: 1.4323 - val_loss: 0.7002 - val_mean_absolute_error: 0.6417 - val_mean_squared_error: 0.7002
# Epoch 3/50
# 436/436 [==============================] - 0s 292us/step - loss: 1.2506 - mean_absolute_error: 0.8403 - mean_squared_error: 1.2506 - val_loss: 0.6515 - val_mean_absolute_error: 0.6205 - val_mean_squared_error: 0.6515
# Epoch 4/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.1444 - mean_absolute_error: 0.8124 - mean_squared_error: 1.1444 - val_loss: 0.6356 - val_mean_absolute_error: 0.6111 - val_mean_squared_error: 0.6356
# Epoch 5/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.1098 - mean_absolute_error: 0.8041 - mean_squared_error: 1.1098 - val_loss: 0.6291 - val_mean_absolute_error: 0.6079 - val_mean_squared_error: 0.6291
# Epoch 6/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.1039 - mean_absolute_error: 0.8027 - mean_squared_error: 1.1039 - val_loss: 0.6261 - val_mean_absolute_error: 0.6063 - val_mean_squared_error: 0.6261
# Epoch 7/50
# 436/436 [==============================] - 0s 292us/step - loss: 1.1016 - mean_absolute_error: 0.8021 - mean_squared_error: 1.1016 - val_loss: 0.6236 - val_mean_absolute_error: 0.6053 - val_mean_squared_error: 0.6236
# Epoch 8/50
# 436/436 [==============================] - 0s 298us/step - loss: 1.1007 - mean_absolute_error: 0.8016 - mean_squared_error: 1.1007 - val_loss: 0.6213 - val_mean_absolute_error: 0.6044 - val_mean_squared_error: 0.6213
# Epoch 9/50
# 436/436 [==============================] - 0s 293us/step - loss: 1.0998 - mean_absolute_error: 0.8014 - mean_squared_error: 1.0998 - val_loss: 0.6192 - val_mean_absolute_error: 0.6034 - val_mean_squared_error: 0.6192
# Epoch 10/50
# 436/436 [==============================] - 0s 294us/step - loss: 1.0993 - mean_absolute_error: 0.8010 - mean_squared_error: 1.0993 - val_loss: 0.6183 - val_mean_absolute_error: 0.6030 - val_mean_squared_error: 0.6183
# Epoch 11/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0994 - mean_absolute_error: 0.8011 - mean_squared_error: 1.0994 - val_loss: 0.6183 - val_mean_absolute_error: 0.6030 - val_mean_squared_error: 0.6183
# Epoch 12/50
# 436/436 [==============================] - 0s 296us/step - loss: 1.0994 - mean_absolute_error: 0.8010 - mean_squared_error: 1.0994 - val_loss: 0.6175 - val_mean_absolute_error: 0.6026 - val_mean_squared_error: 0.6175
# Epoch 13/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0992 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0992 - val_loss: 0.6162 - val_mean_absolute_error: 0.6022 - val_mean_squared_error: 0.6162
# Epoch 14/50
# 436/436 [==============================] - 0s 288us/step - loss: 1.0995 - mean_absolute_error: 0.8010 - mean_squared_error: 1.0995 - val_loss: 0.6167 - val_mean_absolute_error: 0.6023 - val_mean_squared_error: 0.6167
# Epoch 15/50
# 436/436 [==============================] - 0s 287us/step - loss: 1.0993 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0993 - val_loss: 0.6149 - val_mean_absolute_error: 0.6017 - val_mean_squared_error: 0.6149
# Epoch 16/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.0991 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0991 - val_loss: 0.6155 - val_mean_absolute_error: 0.6019 - val_mean_squared_error: 0.6155
# Epoch 17/50
# 436/436 [==============================] - 0s 294us/step - loss: 1.0993 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0993 - val_loss: 0.6149 - val_mean_absolute_error: 0.6017 - val_mean_squared_error: 0.6149
# Epoch 18/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0991 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0991 - val_loss: 0.6157 - val_mean_absolute_error: 0.6019 - val_mean_squared_error: 0.6157
# Epoch 19/50
# 436/436 [==============================] - 0s 296us/step - loss: 1.0993 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0993 - val_loss: 0.6156 - val_mean_absolute_error: 0.6018 - val_mean_squared_error: 0.6156
# Epoch 20/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.0992 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0992 - val_loss: 0.6155 - val_mean_absolute_error: 0.6018 - val_mean_squared_error: 0.6155
# Epoch 21/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.0994 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0994 - val_loss: 0.6158 - val_mean_absolute_error: 0.6019 - val_mean_squared_error: 0.6158
# Epoch 22/50
# 436/436 [==============================] - 0s 300us/step - loss: 1.0993 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0993 - val_loss: 0.6147 - val_mean_absolute_error: 0.6015 - val_mean_squared_error: 0.6147
# Epoch 23/50
# 436/436 [==============================] - 0s 301us/step - loss: 1.0992 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0992 - val_loss: 0.6146 - val_mean_absolute_error: 0.6014 - val_mean_squared_error: 0.6146
# Epoch 24/50
# 436/436 [==============================] - 0s 296us/step - loss: 1.0994 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0994 - val_loss: 0.6141 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6141
# Epoch 25/50
# 436/436 [==============================] - 0s 299us/step - loss: 1.0990 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0990 - val_loss: 0.6140 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6140
# Epoch 26/50
# 436/436 [==============================] - 0s 298us/step - loss: 1.0993 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0993 - val_loss: 0.6141 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6141
# Epoch 27/50
# 436/436 [==============================] - 0s 293us/step - loss: 1.0990 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0990 - val_loss: 0.6140 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6140
# Epoch 28/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0992 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0992 - val_loss: 0.6135 - val_mean_absolute_error: 0.6010 - val_mean_squared_error: 0.6135
# Epoch 29/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0991 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0991 - val_loss: 0.6133 - val_mean_absolute_error: 0.6009 - val_mean_squared_error: 0.6133
# Epoch 30/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0991 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0991 - val_loss: 0.6145 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6145
# Epoch 31/50
# 436/436 [==============================] - 0s 300us/step - loss: 1.0993 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0993 - val_loss: 0.6145 - val_mean_absolute_error: 0.6012 - val_mean_squared_error: 0.6145
# Epoch 32/50
# 436/436 [==============================] - 0s 297us/step - loss: 1.0993 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0993 - val_loss: 0.6131 - val_mean_absolute_error: 0.6007 - val_mean_squared_error: 0.6131
# Epoch 33/50
# 436/436 [==============================] - 0s 305us/step - loss: 1.0993 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0993 - val_loss: 0.6139 - val_mean_absolute_error: 0.6009 - val_mean_squared_error: 0.6139
# Epoch 34/50
# 436/436 [==============================] - 0s 293us/step - loss: 1.0992 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0992 - val_loss: 0.6132 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6132
# Epoch 35/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0992 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0992 - val_loss: 0.6132 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6132
# Epoch 36/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0993 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0993 - val_loss: 0.6122 - val_mean_absolute_error: 0.6003 - val_mean_squared_error: 0.6122
# Epoch 37/50
# 436/436 [==============================] - 0s 293us/step - loss: 1.0990 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0990 - val_loss: 0.6130 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6130
# Epoch 38/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0996 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0996 - val_loss: 0.6127 - val_mean_absolute_error: 0.6005 - val_mean_squared_error: 0.6127
# Epoch 39/50
# 436/436 [==============================] - 0s 291us/step - loss: 1.0991 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0991 - val_loss: 0.6127 - val_mean_absolute_error: 0.6005 - val_mean_squared_error: 0.6127
# Epoch 40/50
# 436/436 [==============================] - 0s 298us/step - loss: 1.0989 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0989 - val_loss: 0.6130 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6130
# Epoch 41/50
# 436/436 [==============================] - 0s 293us/step - loss: 1.0990 - mean_absolute_error: 0.8005 - mean_squared_error: 1.0990 - val_loss: 0.6127 - val_mean_absolute_error: 0.6005 - val_mean_squared_error: 0.6127
# Epoch 42/50
# 436/436 [==============================] - 0s 292us/step - loss: 1.0993 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0993 - val_loss: 0.6137 - val_mean_absolute_error: 0.6008 - val_mean_squared_error: 0.6137
# Epoch 43/50
# 436/436 [==============================] - 0s 292us/step - loss: 1.0993 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0993 - val_loss: 0.6131 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6131
# Epoch 44/50
# 436/436 [==============================] - 0s 296us/step - loss: 1.0994 - mean_absolute_error: 0.8010 - mean_squared_error: 1.0994 - val_loss: 0.6138 - val_mean_absolute_error: 0.6008 - val_mean_squared_error: 0.6138
# Epoch 45/50
# 436/436 [==============================] - 0s 289us/step - loss: 1.0990 - mean_absolute_error: 0.8007 - mean_squared_error: 1.0990 - val_loss: 0.6130 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6130
# Epoch 46/50
# 436/436 [==============================] - 0s 294us/step - loss: 1.0992 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0992 - val_loss: 0.6128 - val_mean_absolute_error: 0.6005 - val_mean_squared_error: 0.6128
# Epoch 47/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0992 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0992 - val_loss: 0.6125 - val_mean_absolute_error: 0.6004 - val_mean_squared_error: 0.6125
# Epoch 48/50
# 436/436 [==============================] - 0s 300us/step - loss: 1.0992 - mean_absolute_error: 0.8008 - mean_squared_error: 1.0992 - val_loss: 0.6140 - val_mean_absolute_error: 0.6009 - val_mean_squared_error: 0.6140
# Epoch 49/50
# 436/436 [==============================] - 0s 295us/step - loss: 1.0990 - mean_absolute_error: 0.8006 - mean_squared_error: 1.0990 - val_loss: 0.6132 - val_mean_absolute_error: 0.6006 - val_mean_squared_error: 0.6132
# Epoch 50/50
# 436/436 [==============================] - 0s 288us/step - loss: 1.0993 - mean_absolute_error: 0.8009 - mean_squared_error: 1.0993 - val_loss: 0.6133 - val_mean_absolute_error: 0.6007 - val_mean_squared_error: 0.6133

# %%
# Выводим динамику среднего абсолютного отклонения от номера эпохи обучения.
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error']) 
plt.title('Model MAE') 
plt.ylabel('MAE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Выводим динамику среднеквадратического отклонения, т.е. значения функции потерь, от номера эпохи обучения.
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error']) 
plt.title('Model MSE') 
plt.ylabel('MSE') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper right') 
plt.show()

# %%
# Предсказание уже обученной нейронной сети на обучающей выборке:
Y_pred_train = model.predict(X_train).flatten()

# %%
# Сравним эталонные значения Y_train и результат работы обученной нейронной сети Y_pred_train для обучающей выборки.
plt.plot(Y_train, Y_pred_train, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_train и Y_pred_train.
plt.plot(Y_train)
plt.plot(Y_pred_train)
plt.show()

# %%
# Предсказание обученной нейронной сети на тестовой выборке:
Y_pred_test = model.predict(X_test).flatten()

# %%
# Сравним эталонные значения Y_test и результат работы обученной нейронной сети Y_pred_test для тестовой выборки.
plt.plot(Y_test, Y_pred_test, 'bo')
plt.plot([-2,2], [-2,2], 'r-')
plt.title('Test vs Pred_test') 
plt.ylabel('Pred_test') 
plt.xlabel('Test') 
plt.show()

# %%
# Выведем сами значения Y_test и Y_pred_test.
plt.plot(Y_test)
plt.plot(Y_pred_test)
plt.show()

# %%
# Сравним среднеквадратичные ошибки (значения функции потерь) для обучающей и тестовой выборок.
print(np.sqrt(mean_squared_error(Y_train, Y_pred_train)))
print(np.sqrt(mean_squared_error(Y_test, Y_pred_test)))
# Out:
# 1.048206084765828
# 0.7831364324745368

# %%
# Проверим на нормальное распределение разности пар (Y_train, Y_pred_train), (Y_test, Y_pred_test)
k_train, p_train = stats.shapiro(Y_train - Y_pred_train)
print('Train k = {0}, p = {1}'.format(k_train, p_train))

k_test, p_test = stats.shapiro(Y_test - Y_pred_test)
print('Test k = {0}, p = {1}'.format(k_test, p_test))
# Out:
# Train k = 0.971213161945343, p = 1.4511817880702438e-07
# Test k = 0.9800465703010559, p = 0.09831693023443222

# %%
# Для полной выборки (Y, Y_pred) применим два статистических теста: shapiro и normaltest.
Y_pred = model.predict(X).flatten()

k_s, p_s = stats.shapiro(Y - Y_pred)
print('k_s = {0}, p_s = {1}'.format(k_s, p_s))

k_n, p_n = stats.normaltest(Y - Y_pred)
print('k_n = {0}, p_n = {1}'.format(k_n, p_n))
# Out:
# k_s = 0.9711742401123047, p_s = 6.969744337226302e-09
# k_n = 48.81581399569146, p_n = 2.510618218703987e-11

# %%
# И тоже самое визуально, с помощью грфиков квантиль-квантиль.
# Обучающая выборка
qqplot(Y_train - Y_pred_train)
plt.show()

# %%
# Тестовая выборка
qqplot(Y_test - Y_pred_test)
plt.show()

# %%
# Полная выборка
qqplot(Y - Y_pred)
plt.show()

# %%
plt.hist(Y - Y_pred, bins=50)
plt.show()

# %%
model.save('1_SimpleNeuralNetwork.h5')
