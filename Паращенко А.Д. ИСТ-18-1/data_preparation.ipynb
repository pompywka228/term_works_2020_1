# %%
# Загрузка зависимостей
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
# Загрузка и анализ набора данных
museum_dataset = pd.read_csv('Набор_4_болезни_сердца.csv',  sep=';')
museum_dataset.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
# 7   44    1   1       120   263    0        1      173      0      0.0      2
# 8   52    1   2       172   199    1        1      162      0      0.5      2
# 9   57    1   2       150   168    0        1      174      0      1.6      2
#
#    ca  num
# 0   0    1
# 1   0    1
# 2   0    1
# 3   0    1
# 4   0    1
# 5   0    1
# 6   0    1
# 7   0    1
# 8   0    1
# 9   0    1

# %%
# Создаем набор данных, в котором будут храниться обработанные данные
dataset = pd.DataFrame()

# %%
data = museum_dataset['age']
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(np.log(data)).reshape(-1, 1)
dataset['age'] = StandardScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age
# 0  0.927622
# 1 -2.117138
# 2 -1.529863
# 3  0.253797
# 4  0.355054
# 5  0.355054
# 6  0.253797
# 7 -1.125867
# 8 -0.170168
# 9  0.355054

# %%
data = museum_dataset['sex']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 200000)
plt.hist(data, bins = 50)
plt.show()

# %%
data = data.replace(0, data.mean())
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['sex'] = MinMaxScaler().fit_transform(data).flatten()

# %%
dataset.head(10)
# Out:
#         age  sex
# 0  0.927622  1.0
# 1 -2.117138  1.0
# 2 -1.529863  0.0
# 3  0.253797  1.0
# 4  0.355054  0.0
# 5  0.355054  1.0
# 6  0.253797  0.0
# 7 -1.125867  1.0
# 8 -0.170168  1.0
# 9  0.355054  1.0

# %%
data = museum_dataset['cp']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 100000)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['cp'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp
# 0  0.927622  1.0  1.000000
# 1 -2.117138  1.0  0.816497
# 2 -1.529863  0.0  0.577350
# 3  0.253797  1.0  0.577350
# 4  0.355054  0.0  0.000000
# 5  0.355054  1.0  0.000000
# 6  0.253797  0.0  0.577350
# 7 -1.125867  1.0  0.577350
# 8 -0.170168  1.0  0.816497
# 9  0.355054  1.0  0.816497

# %%
data = museum_dataset['trestbps']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 181)
plt.hist(data, bins = 50)
plt.show()

# %%
data = data.replace(0, data.mean())
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['trestbps'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps
# 0  0.927622  1.0  1.000000  0.624287
# 1 -2.117138  1.0  0.816497  0.454038
# 2 -1.529863  0.0  0.577350  0.454038
# 3  0.253797  1.0  0.577350  0.335019
# 4  0.355054  0.0  0.000000  0.335019
# 5  0.355054  1.0  0.000000  0.568560
# 6  0.253797  0.0  0.577350  0.568560
# 7 -1.125867  1.0  0.577350  0.335019
# 8 -0.170168  1.0  0.816497  0.909866
# 9  0.355054  1.0  0.816497  0.679061

# %%
data = museum_dataset['chol']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 350)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['chol'] = StandardScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol
# 0  0.927622  1.0  1.000000  0.624287 -0.206993
# 1 -2.117138  1.0  0.816497  0.454038  0.159591
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692
# 3  0.253797  1.0  0.577350  0.335019 -0.141353
# 4  0.355054  0.0  0.000000  0.335019  2.100829
# 5  0.355054  1.0  0.000000  0.568560 -1.150460
# 6  0.253797  0.0  0.577350  0.568560  1.054214
# 7 -1.125867  1.0  0.577350  0.335019  0.431579
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712
# 9  0.355054  1.0  0.816497  0.679061 -1.750157

# %%
data = museum_dataset['fbs']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['fbs'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0

# %%
data = museum_dataset['restecg']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 200000)
plt.hist(data, bins = 50)
plt.show()

# %%
data = data.replace(0, data.mean())
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['restecg'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544

# %%
data = museum_dataset['thalach']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 80, 210)
plt.hist(data, bins = 50)
plt.show()

# %%
data = data.replace(0, data.mean())
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(np.log(data)).reshape(-1, 1)
dataset['thalach'] = StandardScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123

# %%
data = museum_dataset['exang']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['exang'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  exang
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789    0.0
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548    0.0
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137    0.0
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680    0.0
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134    1.0
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368    0.0
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382    0.0
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733    0.0
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348    0.0
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123    0.0

# %%
data = museum_dataset['oldpeak']
plt.hist(data, bins = 50)
plt.show()

# %%
data = data.replace(0, data.mean())
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()
plt.hist(np.log(data), bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['oldpeak'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123
#
#    exang   oldpeak
# 0    0.0  0.552201
# 1    0.0  0.715169
# 2    0.0  0.398844
# 3    0.0  0.265991
# 4    1.0  0.210865
# 5    0.0  0.145476
# 6    0.0  0.379044
# 7    0.0  0.323580
# 8    0.0  0.179818
# 9    0.0  0.436427

# %%
data = museum_dataset['slope']
plt.hist(data, bins = 50)
plt.show()

# %%
data = np.clip(data, 0, 100000)
plt.hist(data, bins = 50)
plt.show()

# %%
plt.hist(data ** 0.5, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['slope'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123
#
#    exang   oldpeak     slope
# 0    0.0  0.552201  0.000000
# 1    0.0  0.715169  0.000000
# 2    0.0  0.398844  1.000000
# 3    0.0  0.265991  1.000000
# 4    1.0  0.210865  1.000000
# 5    0.0  0.145476  0.707107
# 6    0.0  0.379044  0.707107
# 7    0.0  0.323580  1.000000
# 8    0.0  0.179818  1.000000
# 9    0.0  0.436427  1.000000

# %%
data = museum_dataset['ca']
plt.hist(data ** 0.5, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['ca'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123
#
#    exang   oldpeak     slope   ca
# 0    0.0  0.552201  0.000000  0.0
# 1    0.0  0.715169  0.000000  0.0
# 2    0.0  0.398844  1.000000  0.0
# 3    0.0  0.265991  1.000000  0.0
# 4    1.0  0.210865  1.000000  0.0
# 5    0.0  0.145476  0.707107  0.0
# 6    0.0  0.379044  0.707107  0.0
# 7    0.0  0.323580  1.000000  0.0
# 8    0.0  0.179818  1.000000  0.0
# 9    0.0  0.436427  1.000000  0.0

# %%
data = museum_dataset['num']
plt.hist(data ** 0.5, bins = 50)
plt.show()

# %%
data = np.array(data ** 0.5).reshape(-1, 1)
dataset['num'] = MinMaxScaler().fit_transform(data).flatten()
dataset.head(10)
# Out:
#         age  sex        cp  trestbps      chol  fbs   restecg   thalach  \
# 0  0.927622  1.0  1.000000  0.624287 -0.206993  1.0  0.000000  0.090789
# 1 -2.117138  1.0  0.816497  0.454038  0.159591  0.0  0.397544  1.444548
# 2 -1.529863  0.0  0.577350  0.454038 -0.864692  0.0  0.000000  0.931137
# 3  0.253797  1.0  0.577350  0.335019 -0.141353  0.0  0.397544  1.141680
# 4  0.355054  0.0  0.000000  0.335019  2.100829  0.0  0.397544  0.601134
# 5  0.355054  1.0  0.000000  0.568560 -1.150460  0.0  0.397544  0.008368
# 6  0.253797  0.0  0.577350  0.568560  1.054214  0.0  0.000000  0.212382
# 7 -1.125867  1.0  0.577350  0.335019  0.431579  0.0  0.397544  0.966733
# 8 -0.170168  1.0  0.816497  0.909866 -0.982712  1.0  0.397544  0.563348
# 9  0.355054  1.0  0.816497  0.679061 -1.750157  0.0  0.397544  1.002123
#
#    exang   oldpeak     slope   ca  num
# 0    0.0  0.552201  0.000000  0.0  1.0
# 1    0.0  0.715169  0.000000  0.0  1.0
# 2    0.0  0.398844  1.000000  0.0  1.0
# 3    0.0  0.265991  1.000000  0.0  1.0
# 4    1.0  0.210865  1.000000  0.0  1.0
# 5    0.0  0.145476  0.707107  0.0  1.0
# 6    0.0  0.379044  0.707107  0.0  1.0
# 7    0.0  0.323580  1.000000  0.0  1.0
# 8    0.0  0.179818  1.000000  0.0  1.0
# 9    0.0  0.436427  1.000000  0.0  1.0

# %%
dataset.to_csv('prepared_data.csv', index=False)
